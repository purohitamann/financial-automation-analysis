# %% [markdown]
# # Install Libraries

# %%
! pip install yfinance langchain_pinecone openai python-dotenv langchain-community sentence_transformers
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.50)
# Requirement already satisfied: langchain_pinecone in /usr/local/lib/python3.10/dist-packages (0.2.0)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.5)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.3.10)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: aiohttp<3.10,>=3.9.5 in /usr/local/lib/python3.10/dist-packages (from langchain_pinecone) (3.9.5)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /usr/local/lib/python3.10/dist-packages (from langchain_pinecone) (0.3.22)
# Requirement already satisfied: pinecone-client<6.0.0,>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain_pinecone) (5.0.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.28.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.8.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.10.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.36)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.10 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.10)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.147)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.46.3)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.1.0)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.1.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.26.3)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.18.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (4.0.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.10->langchain-community) (0.3.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Requirement already satisfied: pinecone-plugin-inference<2.0.0,>=1.0.3 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (1.1.0)
# Requirement already satisfied: pinecone-plugin-interface<0.0.8,>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (0.0.7)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (2.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /usr/local/lib/python3.10/dist-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence_transformers) (12.6.85)
# ERROR: Operation cancelled by user
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3070, in _dep_map
#     return self.__dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2863, in __getattr__
#     raise AttributeError(attr)
# AttributeError: _DistInfoDistribution__dep_map
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/commands/install.py", line 377, in run
#     requirement_set = resolver.resolve(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/resolver.py", line 95, in resolve
#     result = self._result = resolver.resolve(
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 546, in resolve
#     state = resolution.resolve(requirements, max_rounds=max_rounds)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 427, in resolve
#     failure_causes = self._attempt_to_pin_criterion(name)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 239, in _attempt_to_pin_criterion
#     criteria = self._get_updated_criteria(candidate)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/resolvelib/resolvers.py", line 229, in _get_updated_criteria
#     for requirement in self._p.get_dependencies(candidate=candidate):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/provider.py", line 247, in get_dependencies
#     return [r for r in candidate.iter_dependencies(with_requires) if r is not None]
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/provider.py", line 247, in <listcomp>
#     return [r for r in candidate.iter_dependencies(with_requires) if r is not None]
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/resolution/resolvelib/candidates.py", line 401, in iter_dependencies
#     for r in self.dist.iter_dependencies():
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/metadata/pkg_resources.py", line 247, in iter_dependencies
#     return self._dist.requires(extras)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 2786, in requires
#     dm = self._dep_map
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3072, in _dep_map
#     self.__dep_map = self._compute_dependencies()
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3094, in _compute_dependencies
#     dm[s_extra] = [r for r in reqs_for_extra(extra) if r not in common]
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3094, in <listcomp>
#     dm[s_extra] = [r for r in reqs_for_extra(extra) if r not in common]
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/pkg_resources/__init__.py", line 3086, in reqs_for_extra
#     if not req.marker or req.marker.evaluate({'extra': extra}):
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/packaging/markers.py", line 310, in evaluate
#     current_environment = cast("dict[str, str]", default_environment())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_vendor/packaging/markers.py", line 255, in default_environment
#     "python_version": ".".join(platform.python_version_tuple()[:2]),
#   File "/usr/lib/python3.10/platform.py", line 1127, in python_version_tuple
#     return tuple(_sys_version()[1].split('.'))
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/cli/base_command.py", line 216, in exc_logging_wrapper
#     logger.debug("Exception information:", exc_info=True)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1465, in debug
#     self._log(DEBUG, msg, args, **kwargs)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1624, in _log
#     self.handle(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1634, in handle
#     self.callHandlers(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1696, in callHandlers
#     hdlr.handle(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 968, in handle
#     self.emit(record)
#   File "/usr/lib/python3.10/logging/handlers.py", line 75, in emit
#     logging.FileHandler.emit(self, record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1218, in emit
#     StreamHandler.emit(self, record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/usr/local/lib/python3.10/dist-packages/pip/_internal/utils/logging.py", line 112, in format
#     formatted = super().format(record)
#   File "/usr/lib/python3.10/logging/__init__.py", line 686, in format
#     record.exc_text = self.formatException(record.exc_info)
#   File "/usr/lib/python3.10/logging/__init__.py", line 636, in formatException
#     traceback.print_exception(ei[0], ei[1], tb, None, sio)
#   File "/usr/lib/python3.10/traceback.py", line 119, in print_exception
#     te = TracebackException(type(value), value, tb, limit=limit, compact=True)
#   File "/usr/lib/python3.10/traceback.py", line 502, in __init__
#     self.stack = StackSummary.extract(
#   File "/usr/lib/python3.10/traceback.py", line 383, in extract
#     f.line
#   File "/usr/lib/python3.10/traceback.py", line 306, in line
#     self._line = linecache.getline(self.filename, self.lineno)
#   File "/usr/lib/python3.10/linecache.py", line 30, in getline
#     lines = getlines(filename, module_globals)
#   File "/usr/lib/python3.10/linecache.py", line 46, in getlines
#     return updatecache(filename, module_globals)
#   File "/usr/lib/python3.10/linecache.py", line 136, in updatecache
#     with tokenize.open(fullname) as fp:
#   File "/usr/lib/python3.10/tokenize.py", line 396, in open
#     encoding, lines = detect_encoding(buffer.readline)
#   File "/usr/lib/python3.10/tokenize.py", line 365, in detect_encoding
#     first = read_or_stop()
#   File "/usr/lib/python3.10/tokenize.py", line 323, in read_or_stop
#     return readline()
# KeyboardInterrupt
# ^C

# %%
from langchain_pinecone import PineconeVectorStore
from openai import OpenAI
import dotenv
import json
import yfinance as yf
import concurrent.futures
from langchain_community.embeddings import HuggingFaceEmbeddings
from google.colab import userdata
from langchain.schema import Document
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone
import numpy as np
import requests
import os

# %%
def get_stock_info(symbol: str) -> dict:
    """
    Retrieves and formats detailed information about a stock from Yahoo Finance.

    Args:
        symbol (str): The stock ticker symbol to look up.

    Returns:
        dict: A dictionary containing detailed stock information, including ticker, name,
              business summary, city, state, country, industry, and sector.
    """
    data = yf.Ticker(symbol)
    stock_info = data.info

    properties = {
        "Ticker": stock_info.get('symbol', 'Information not available'),
        'Name': stock_info.get('longName', 'Information not available'),
        'Business Summary': stock_info.get('longBusinessSummary'),
        'City': stock_info.get('city', 'Information not available'),
        'State': stock_info.get('state', 'Information not available'),
        'Country': stock_info.get('country', 'Information not available'),
        'Industry': stock_info.get('industry', 'Information not available'),
        'Sector': stock_info.get('sector', 'Information not available')
    }

    return properties

# %%
data = yf.Ticker("NVDA")
stock_info = data.info
print(stock_info)
# Out:
# {'address1': '2788 San Tomas Expressway', 'city': 'Santa Clara', 'state': 'CA', 'zip': '95051', 'country': 'United States', 'phone': '408 486 2000', 'website': 'https://www.nvidia.com', 'industry': 'Semiconductors', 'industryKey': 'semiconductors', 'industryDisp': 'Semiconductors', 'sector': 'Technology', 'sectorKey': 'technology', 'sectorDisp': 'Technology', 'longBusinessSummary': "NVIDIA Corporation provides graphics and compute and networking solutions in the United States, Taiwan, China, Hong Kong, and internationally. The Graphics segment offers GeForce GPUs for gaming and PCs, the GeForce NOW game streaming service and related infrastructure, and solutions for gaming platforms; Quadro/NVIDIA RTX GPUs for enterprise workstation graphics; virtual GPU or vGPU software for cloud-based visual and virtual computing; automotive platforms for infotainment systems; and Omniverse software for building and operating metaverse and 3D internet applications. The Compute & Networking segment comprises Data Center computing platforms and end-to-end networking platforms, including Quantum for InfiniBand and Spectrum for Ethernet; NVIDIA DRIVE automated-driving platform and automotive development agreements; Jetson robotics and other embedded platforms; NVIDIA AI Enterprise and other software; and DGX Cloud software and services. The company's products are used in gaming, professional visualization, data center, and automotive markets. It sells its products to original equipment manufacturers, original device manufacturers, system integrators and distributors, independent software vendors, cloud service providers, consumer internet companies, add-in board manufacturers, distributors, automotive manufacturers and tier-1 automotive suppliers, and other ecosystem participants. NVIDIA Corporation was incorporated in 1993 and is headquartered in Santa Clara, California.", 'fullTimeEmployees': 29600, 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Jen-Hsun  Huang', 'age': 60, 'title': 'Co-Founder, CEO, President & Director', 'yearBorn': 1963, 'fiscalYear': 2024, 'totalPay': 7491487, 'exercisedValue': 217327152, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Colette M. Kress', 'age': 56, 'title': 'Executive VP & CFO', 'yearBorn': 1967, 'fiscalYear': 2024, 'totalPay': 1510765, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Debora  Shoquist', 'age': 68, 'title': 'Executive Vice President of Operations', 'yearBorn': 1955, 'fiscalYear': 2024, 'totalPay': 1371266, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Timothy S. Teter J.D.', 'age': 56, 'title': 'Executive VP, General Counsel & Secretary', 'yearBorn': 1967, 'fiscalYear': 2024, 'totalPay': 1360939, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Ajay K. Puri', 'age': 68, 'title': 'Executive Vice President of Worldwide Field Operations', 'yearBorn': 1955, 'fiscalYear': 2024, 'totalPay': 2295097, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Chris A. Malachowsky', 'title': 'Co-Founder', 'fiscalYear': 2024, 'totalPay': 320000, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Donald F. Robertson Jr.', 'age': 54, 'title': 'VP & Chief Accounting Officer', 'yearBorn': 1969, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Prof. William J. Dally Ph.D.', 'age': 62, 'title': 'Chief Scientist & Senior VP of Research', 'yearBorn': 1961, 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Mylene  Mangalindan', 'title': 'VP of Corporate Communications', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Tommy  Lee', 'title': 'Senior Vice President of Systems Engineering & Application', 'fiscalYear': 2024, 'exercisedValue': 0, 'unexercisedValue': 0}], 'auditRisk': 7, 'boardRisk': 10, 'compensationRisk': 5, 'shareHolderRightsRisk': 6, 'overallRisk': 8, 'governanceEpoc ...

# %%
def get_huggingface_embeddings(text, model_name="sentence-transformers/all-mpnet-base-v2"):
    """
    Generates embeddings for the given text using a specified Hugging Face model.

    Args:
        text (str): The input text to generate embeddings for.
        model_name (str): The name of the Hugging Face model to use.
                          Defaults to "sentence-transformers/all-mpnet-base-v2".

    Returns:
        np.ndarray: The generated embeddings as a NumPy array.
    """
    model = SentenceTransformer(model_name)
    return model.encode(text)


def cosine_similarity_between_sentences(sentence1, sentence2):
    """
    Calculates the cosine similarity between two sentences.

    Args:
        sentence1 (str): The first sentence for similarity comparison.
        sentence2 (str): The second sentence for similarity comparison.

    Returns:
        float: The cosine similarity score between the two sentences,
               ranging from -1 (completely opposite) to 1 (identical).

    Notes:
        Prints the similarity score to the console in a formatted string.
    """
    # Get embeddings for both sentences
    embedding1 = np.array(get_huggingface_embeddings(sentence1))
    embedding2 = np.array(get_huggingface_embeddings(sentence2))

    # Reshape embeddings for cosine_similarity function
    embedding1 = embedding1.reshape(1, -1)
    embedding2 = embedding2.reshape(1, -1)

    # Calculate cosine similarity
    similarity = cosine_similarity(embedding1, embedding2)
    similarity_score = similarity[0][0]
    print(f"Cosine similarity between the two sentences: {similarity_score:.4f}")
    return similarity_score


# Example usage
sentence1 = "I like walking to the park"
sentence2 = "I like running to the office"

similarity = cosine_similarity_between_sentences(sentence1, sentence2)
# Out:
# Cosine similarity between the two sentences: 0.6133

# %%
aapl_info = get_stock_info('AAPL')
print(aapl_info)
# Out:
# {'Ticker': 'AAPL', 'Name': 'Apple Inc.', 'Business Summary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.', 'City': 'Cupertino', 'State': 'CA', 'Country': 'United States', 'Industry': 'Consumer Electronics', 'Sector': 'Technology'}

# %%
aapl_description = aapl_info['Business Summary']

company_description = "I want to find companies that make smartphones and are headquarted in California"

similarity = cosine_similarity_between_sentences(aapl_description, company_description)
# Out:
# Cosine similarity between the two sentences: 0.3635

# %% [markdown]
# # Get all the Stocks in the Stock Market

# %% [markdown]
# First, we need to get the symbols (also known as tickers) of all the stocks in the stock market

# %%
def get_company_tickers():
    """
    Downloads and parses the Stock ticker symbols from the GitHub-hosted SEC company tickers JSON file.

    Returns:
        dict: A dictionary containing company tickers and related information.

    Notes:
        The data is sourced from the official SEC website via a GitHub repository:
        https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json
    """
    # URL to fetch the raw JSON file from GitHub
    url = "https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json"

    # Making a GET request to the URL
    response = requests.get(url)

    # Checking if the request was successful
    if response.status_code == 200:
        # Parse the JSON content directly
        company_tickers = json.loads(response.content.decode('utf-8'))

        # Optionally save the content to a local file for future use
        with open("company_tickers.json", "w", encoding="utf-8") as file:
            json.dump(company_tickers, file, indent=4)

        print("File downloaded successfully and saved as 'company_tickers.json'")
        return company_tickers
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
        return None

company_tickers = get_company_tickers()
# Out:
# File downloaded successfully and saved as 'company_tickers.json'

# %%
company_tickers
# Out:
# {'0': {'cik_str': 1045810, 'ticker': 'NVDA', 'title': 'NVIDIA CORP'},
#  '1': {'cik_str': 320193, 'ticker': 'AAPL', 'title': 'Apple Inc.'},
#  '2': {'cik_str': 789019, 'ticker': 'MSFT', 'title': 'MICROSOFT CORP'},
#  '3': {'cik_str': 1018724, 'ticker': 'AMZN', 'title': 'AMAZON COM INC'},
#  '4': {'cik_str': 1652044, 'ticker': 'GOOGL', 'title': 'Alphabet Inc.'},
#  '5': {'cik_str': 1326801, 'ticker': 'META', 'title': 'Meta Platforms, Inc.'},
#  '6': {'cik_str': 1318605, 'ticker': 'TSLA', 'title': 'Tesla, Inc.'},
#  '7': {'cik_str': 1067983,
#   'ticker': 'BRK-B',
#   'title': 'BERKSHIRE HATHAWAY INC'},
#  '8': {'cik_str': 1046179,
#   'ticker': 'TSM',
#   'title': 'TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD'},
#  '9': {'cik_str': 1730168, 'ticker': 'AVGO', 'title': 'Broadcom Inc.'},
#  '10': {'cik_str': 59478, 'ticker': 'LLY', 'title': 'ELI LILLY & Co'},
#  '11': {'cik_str': 19617, 'ticker': 'JPM', 'title': 'JPMORGAN CHASE & CO'},
#  '12': {'cik_str': 104169, 'ticker': 'WMT', 'title': 'Walmart Inc.'},
#  '13': {'cik_str': 1403161, 'ticker': 'V', 'title': 'VISA INC.'},
#  '14': {'cik_str': 731766, 'ticker': 'UNH', 'title': 'UNITEDHEALTH GROUP INC'},
#  '15': {'cik_str': 884394, 'ticker': 'SPY', 'title': 'SPDR S&P 500 ETF TRUST'},
#  '16': {'cik_str': 34088, 'ticker': 'XOM', 'title': 'EXXON MOBIL CORP'},
#  '17': {'cik_str': 1341439, 'ticker': 'ORCL', 'title': 'ORACLE CORP'},
#  '18': {'cik_str': 1141391, 'ticker': 'MA', 'title': 'Mastercard Inc'},
#  '19': {'cik_str': 353278, 'ticker': 'NVO', 'title': 'NOVO NORDISK A S'},
#  '20': {'cik_str': 354950, 'ticker': 'HD', 'title': 'HOME DEPOT, INC.'},
#  '21': {'cik_str': 909832,
#   'ticker': 'COST',
#   'title': 'COSTCO WHOLESALE CORP /NEW'},
#  '22': {'cik_str': 80424, 'ticker': 'PG', 'title': 'PROCTER & GAMBLE Co'},
#  '23': {'cik_str': 200406, 'ticker': 'JNJ', 'title': 'JOHNSON & JOHNSON'},
#  '24': {'cik_str': 70858,
#   'ticker': 'BAC',
#   'title': 'BANK OF AMERICA CORP /DE/'},
#  '25': {'cik_str': 1065280, 'ticker': 'NFLX', 'title': 'NETFLIX INC'},
#  '26': {'cik_str': 1108524, 'ticker': 'CRM', 'title': 'Salesforce, Inc.'},
#  '27': {'cik_str': 1551152, 'ticker': 'ABBV', 'title': 'AbbVie Inc.'},
#  '28': {'cik_str': 2008670, 'ticker': 'RCIT', 'title': 'REELCAUSE INC'},
#  '29': {'cik_str': 93410, 'ticker': 'CVX', 'title': 'CHEVRON CORP'},
#  '30': {'cik_str': 1283699, 'ticker': 'TMUS', 'title': 'T-Mobile US, Inc.'},
#  '31': {'cik_str': 1000184, 'ticker': 'SAP', 'title': 'SAP SE'},
#  '32': {'cik_str': 21344, 'ticker': 'KO', 'title': 'COCA COLA CO'},
#  '33': {'cik_str': 937966, 'ticker': 'ASML', 'title': 'ASML HOLDING NV'},
#  '34': {'cik_str': 72971,
#   'ticker': 'WFC',
#   'title': 'WELLS FARGO & COMPANY/MN'},
#  '35': {'cik_str': 310158, 'ticker': 'MRK', 'title': 'Merck & Co., Inc.'},
#  '36': {'cik_str': 858877, 'ticker': 'CSCO', 'title': 'CISCO SYSTEMS, INC.'},
#  '37': {'cik_str': 1094517, 'ticker': 'TM', 'title': 'TOYOTA MOTOR CORP/'},
#  '38': {'cik_str': 796343, 'ticker': 'ADBE', 'title': 'ADOBE INC.'},
#  '39': {'cik_str': 1467373, 'ticker': 'ACN', 'title': 'Accenture plc'},
#  '40': {'cik_str': 1393818, 'ticker': 'BX', 'title': 'Blackstone Inc.'},
#  '41': {'cik_str': 77476, 'ticker': 'PEP', 'title': 'PEPSICO INC'},
#  '42': {'cik_str': 2488,
#   'ticker': 'AMD',
#   'title': 'ADVANCED MICRO DEVICES INC'},
#  '43': {'cik_str': 895421, 'ticker': 'MS', 'title': 'MORGAN STANLEY'},
#  '44': {'cik_str': 1707925, 'ticker': 'LIN', 'title': 'LINDE PLC'},
#  '45': {'cik_str': 1577552,
#   'ticker': 'BABA',
#   'title': 'Alibaba Group Holding Ltd'},
#  '46': {'cik_str': 63908, 'ticker': 'MCD', 'title': 'MCDONALDS CORP'},
#  '47': {'cik_str': 1114448, 'ticker': 'NVS', 'title': 'NOVARTIS AG'},
#  '48': {'cik_str': 1373715, 'ticker': 'NOW', 'title': 'ServiceNow, Inc.'},
#  '49': {'cik_str': 1744489, 'ticker': 'DIS', 'title': 'Walt Disney Co'},
#  '50': {'cik_str': 4962, 'ticker': 'AXP', 'title': 'AMERICAN EXPRESS CO'},
#  '51': {'cik_str': 1413329,
#   'ticker': 'PM',
#   'title': 'Philip Morris International Inc.'},
#  '52': {'cik_str': 1800, 'ticker': 'ABT', 'title': 'ABBOTT LABORATORIES'},
#  '53': {'cik_str': 1306965, 'ticker': 'SHEL', 'title': 'Shell plc'},
#  '54': {'cik_str': 901832, 'ticker': 'AZN', 'title': 'ASTRAZENECA PLC'},
#  '55': {'cik_str': 97745,
#   'ticker': 'TMO',
#   'title': 'THERMO FISHER SCIENTIFIC INC.'},
#  '56': {'cik_str': 1067839,
#   'ticker': 'QQQ',
#   'title': 'INVESCO QQQ TRUST, SERIES 1'},
#  '57': {'cik_str': 896878, 'ticker': 'INTU', 'title': 'INTUIT INC.'},
#  '58': {'cik_str': 40545, 'ticker': 'GE', 'title': 'GENERAL ELECTRIC CO'},
#  '59': {'cik_str': 51143,
#   'ticker': 'IBM',
#   'title': 'INTERNATIONAL BUSINESS MACHINES CORP'},
#  '60': {'cik_str': 1035267,
#   'ticker': 'ISRG',
#   'title': 'INTUITIVE SURGICAL INC'},
#  '61': {'cik_str': 886982, 'ticker': 'GS', 'title': 'GOLDMAN SACHS GROUP INC'},
#  '62': {'cik_str': 18230, 'ticker': 'CAT', 'title': 'CATERPILLAR INC'},
#  '63': {'cik_str': 97476, 'ticker': 'TXN', 'title': 'TEXAS INSTRUMENTS INC'},
#  '64': {'cik_str': 804328, 'ticker': 'QCOM', 'title': 'QUALCOMM INC/DE'},
#  '65': {'cik_str': 732712,
#   'ticker': 'VZ',
#   'title': 'VERIZON COMMUNICATIONS INC'},
#  '66': {'cik_str': 1000275, 'ticker': 'RY', 'title': 'ROYAL BANK OF CANADA'},
#  '67': {'cik_str': 313616, 'ticker': 'DHR', 'title': 'DANAHER CORP /DE/'},
#  '68': {'cik_str': 1089113, 'ticker': 'HSBC', 'title': 'HSBC HOLDINGS PLC'},
#  '69': {'cik_str': 1075531,
#   'ticker': 'BKNG',
#   'title': 'Booking Holdings Inc.'},
#  '70': {'cik_str': 1061736,
#   'ticker': 'FMX',
#   'title': 'MEXICAN ECONOMIC DEVELOPMENT INC'},
#  '71': {'cik_str': 1166691, 'ticker': 'CMCSA', 'title': 'COMCAST CORP'},
#  '72': {'cik_str': 732717, 'ticker': 'T', 'title': 'AT&T INC.'},
#  '73': {'cik_str': 1737806, 'ticker': 'PDD', 'title': 'PDD Holdings Inc.'},
#  '74': {'cik_str': 1144967, 'ticker': 'HDB', 'title': 'HDFC BANK LTD'},
#  '75': {'cik_str': 753308, 'ticker': 'NEE', 'title': 'NEXTERA ENERGY INC'},
#  '76': {'cik_str': 101829, 'ticker': 'RTX', 'title': 'RTX Corp'},
#  '77': {'cik_str': 64040, 'ticker': 'SPGI', 'title': 'S&P Global Inc.'},
#  '78': {'cik_str': 2012383, 'ticker': 'BLK', 'title': 'BlackRock, Inc.'},
#  '79': {'cik_str': 1543151,
#   'ticker': 'UBER',
#   'title': 'Uber Technologies, Inc'},
#  '80': {'cik_str': 60667, 'ticker': 'LOW', 'title': 'LOWES COMPANIES INC'},
#  '81': {'cik_str': 318154, 'ticker': 'AMGN', 'title': 'AMGEN INC'},
#  '82': {'cik_str': 80661, 'ticker': 'PGR', 'title': 'PROGRESSIVE CORP/OH/'},
#  '83': {'cik_str': 773840,
#   'ticker': 'HON',
#   'title': 'HONEYWELL INTERNATIONAL INC'},
#  '84': {'cik_str': 310764, 'ticker': 'SYK', 'title': 'STRYKER CORP'},
#  '85': {'cik_str': 316709, 'ticker': 'SCHW', 'title': 'SCHWAB CHARLES CORP'},
#  '86': {'cik_str': 1321655,
#   'ticker': 'PLTR',
#   'title': 'Palantir Technologies Inc.'},
#  '87': {'cik_str': 100885, 'ticker': 'UNP', 'title': 'UNION PACIFIC CORP'},
#  '88': {'cik_str': 217410, 'ticker': 'UL', 'title': 'UNILEVER PLC'},
#  '89': {'cik_str': 1551182, 'ticker': 'ETN', 'title': 'Eaton Corp plc'},
#  '90': {'cik_str': 78003, 'ticker': 'PFE', 'title': 'PFIZER INC'},
#  '91': {'cik_str': 6951,
#   'ticker': 'AMAT',
#   'title': 'APPLIED MATERIALS INC /DE'},
#  '92': {'cik_str': 1594805, 'ticker': 'SHOP', 'title': 'SHOPIFY INC.'},
#  '93': {'cik_str': 879764, 'ticker': 'TTE', 'title': 'TotalEnergies SE'},
#  '94': {'cik_str': 1404912, 'ticker': 'KKR', 'title': 'KKR & Co. Inc.'},
#  '95': {'cik_str': 67088,
#   'ticker': 'MUFG',
#   'title': 'MITSUBISHI UFJ FINANCIAL GROUP INC'},
#  '96': {'cik_str': 109198, 'ticker': 'TJX', 'title': 'TJX COMPANIES INC /DE/'},
#  '97': {'cik_str': 1973239, 'ticker': 'ARM', 'title': 'ARM HOLDINGS PLC /UK'},
#  '98': {'cik_str': 811809, 'ticker': 'BHP', 'title': 'BHP Group Ltd'},
#  '99': {'cik_str': 831001, 'ticker': 'C', 'title': 'CITIGROUP INC'},
#  '100': {'cik_str': 1163165, 'ticker': 'COP', 'title': 'CONOCOPHILLIPS'},
#  '101': {'cik_str': 885725,
#   'ticker': 'BSX',
#   'title': 'BOSTON SCIENTIFIC CORP'},
#  '102': {'cik_str': 1327567,
#   'ticker': 'PANW',
#   'title': 'Palo Alto Networks Inc'},
#  '103': {'cik_str': 936468, 'ticker': 'LMT', 'title': 'LOCKHEED MARTIN CORP'},
#  '104': {'cik_str': 1121404, 'ticker': 'SNY', 'title': 'Sanofi'},
#  '105': {'cik_str': 8670,
#   'ticker': 'ADP',
#   'title': 'AUTOMATIC DATA PROCESSING INC'},
#  '106': {'cik_str': 887028, 'ticker': 'RTNTF', 'title': 'RIO TINTO LTD'},
#  '107': {'cik_str': 798354, 'ticker': 'FI', 'title': 'FISERV INC'},
#  '108': {'cik_str': 875320,
#   'ticker': 'VRTX',
#   'title': 'VERTEX PHARMACEUTICALS INC / MA'},
#  '109': {'cik_str': 1596532,
#   'ticker': 'ANET',
#   'title': 'Arista Networks, Inc.'},
#  '110': {'cik_str': 896159, 'ticker': 'CB', 'title': 'Chubb Ltd'},
#  '111': {'cik_str': 1378580, 'ticker': 'EADSY', 'title': 'Airbus SE/ADR'},
#  '112': {'cik_str': 320187, 'ticker': 'NKE', 'title': 'NIKE, Inc.'},
#  '113': {'cik_str': 14272,
#   'ticker': 'BMY',
#   'title': 'BRISTOL MYERS SQUIBB CO'},
#  '114': {'cik_str': 1090727,
#   'ticker': 'UPS',
#   'title': 'UNITED PARCEL SERVICE INC'},
#  '115': {'cik_str': 829224, 'ticker': 'SBUX', 'title': 'STARBUCKS CORP'},
#  '116': {'cik_str': 313838, 'ticker': 'SONY', 'title': 'Sony Group Corp'},
#  '117': {'cik_str': 1613103, 'ticker': 'MDT', 'title': 'Medtronic plc'},
#  '118': {'cik_str': 882095,
#   'ticker': 'GILD',
#   'title': 'GILEAD SCIENCES, INC.'},
#  '119': {'cik_str': 1668717,
#   'ticker': 'BUD',
#   'title': 'Anheuser-Busch InBev SA/NV'},
#  '120': {'cik_str': 315189, 'ticker': 'DE', 'title': 'DEERE & CO'},
#  '121': {'cik_str': 62709,
#   'ticker': 'MMC',
#   'title': 'MARSH & MCLENNAN COMPANIES, INC.'},
#  '122': {'cik_str': 723125, 'ticker': 'MU', 'title': 'MICRON TECHNOLOGY INC'},
#  '123': {'cik_str': 50863, 'ticker': 'INTC', 'title': 'INTEL CORP'},
#  '124': {'cik_str': 1045609, 'ticker': 'PLD', 'title': 'Prologis, Inc.'},
#  '125': {'cik_str': 12927, 'ticker': 'BA', 'title': 'BOEING CO'},
#  '126': {'cik_str': 1103838, 'ticker': 'IBN', 'title': 'ICICI BANK LTD'},
#  '127': {'cik_str': 6281, 'ticker': 'ADI', 'title': 'ANALOG DEVICES INC'},
#  '128': {'cik_str': 1610520, 'ticker': 'UBS', 'title': 'UBS Group AG'},
#  '129': {'cik_str': 863064, 'ticker': 'RIO', 'title': 'RIO TINTO PLC'},
#  '130': {'cik_str': 947263, 'ticker': 'TD', 'title': 'TORONTO DOMINION BANK'},
#  '131': {'cik_str': 1161167,
#   'ticker': 'AIQUY',
#   'title': 'L AIR LIQUIDE SA /FI'},
#  '132': {'cik_str': 92122, 'ticker': 'SO', 'title': 'SOUTHERN CO'},
#  '133': {'cik_str': 89800, 'ticker': 'SHW', 'title': 'SHERWIN WILLIAMS CO'},
#  '134': {'cik_str': 1751008, 'ticker': 'APP', 'title': 'AppLovin Corp'},
#  '135': {'cik_str': 764180, 'ticker': 'MO', 'title': 'ALTRIA GROUP, INC.'},
#  '136': {'cik_str': 1099590, 'ticker': 'MELI', 'title': 'MERCADOLIBRE INC'},
#  '137': {'cik_str': 1156039,
#   'ticker': 'ELV',
#   'title': 'Elevance Health, Inc.'},
#  '138': {'cik_str': 1639920,
#   'ticker': 'SPOT',
#   'title': 'Spotify Technology S.A.'},
#  '139': {'cik_str': 895728, 'ticker': 'ENB', 'title': 'ENBRIDGE INC'},
#  '140': {'cik_str': 1571996,
#   'ticker': 'DELL',
#   'title': 'Dell Technologies Inc.'},
#  '141': {'cik_str': 1996810, 'ticker': 'GEV', 'title': 'GE Vernova Inc.'},
#  '142': {'cik_str': 1858681,
#   'ticker': 'APO',
#   'title': 'Apollo Global Management, Inc.'},
#  '143': {'cik_str': 1466258,
#   'ticker': 'TT',
#   'title': 'Trane Technologies plc'},
#  '144': {'cik_str': 1053507,
#   'ticker': 'AMT',
#   'title': 'AMERICAN TOWER CORP /MA/'},
#  '145': {'cik_str': 1022837,
#   'ticker': 'SMFG',
#   'title': 'SUMITOMO MITSUI FINANCIAL GROUP, INC.'},
#  '146': {'cik_str': 707549, 'ticker': 'LRCX', 'title': 'LAM RESEARCH CORP'},
#  '147': {'cik_str': 1067491, 'ticker': 'INFY', 'title': 'Infosys Ltd'},
#  '148': {'cik_str': 76334, 'ticker': 'PH', 'title': 'PARKER HANNIFIN CORP'},
#  '149': {'cik_str': 1571949,
#   'ticker': 'ICE',
#   'title': 'Intercontinental Exchange, Inc.'},
#  '150': {'cik_str': 1739940, 'ticker': 'CI', 'title': 'Cigna Group'},
#  '151': {'cik_str': 823768, 'ticker': 'WM', 'title': 'WASTE MANAGEMENT INC'},
#  '152': {'cik_str': 1119639,
#   'ticker': 'PBR',
#   'title': 'PETROBRAS - PETROLEO BRASILEIRO SA'},
#  '153': {'cik_str': 1101239, 'ticker': 'EQIX', 'title': 'EQUINIX INC'},
#  '154': {'cik_str': 723254, 'ticker': 'CTAS', 'title': 'CINTAS CORP'},
#  '155': {'cik_str': 860730, 'ticker': 'HCA', 'title': 'HCA Healthcare, Inc.'},
#  '156': {'cik_str': 1326160, 'ticker': 'DUK', 'title': 'Duke Energy CORP'},
#  '157': {'cik_str': 1103982,
#   'ticker': 'MDLZ',
#   'title': 'Mondelez International, Inc.'},
#  '158': {'cik_str': 1001085, 'ticker': 'BN', 'title': 'BROOKFIELD Corp /ON/'},
#  '159': {'cik_str': 1633917,
#   'ticker': 'PYPL',
#   'title': 'PayPal Holdings, Inc.'},
#  '160': {'cik_str': 1059556, 'ticker': 'MCO', 'title': 'MOODYS CORP /DE/'},
#  '161': {'cik_str': 820313, 'ticker': 'APH', 'title': 'AMPHENOL CORP /DE/'},
#  '162': {'cik_str': 766704, 'ticker': 'WELL', 'title': 'WELLTOWER INC.'},
#  '163': {'cik_str': 872589,
#   'ticker': 'REGN',
#   'title': 'REGENERON PHARMACEUTICALS, INC.'},
#  '164': {'cik_str': 1559720, 'ticker': 'ABNB', 'title': 'Airbnb, Inc.'},
#  '165': {'cik_str': 319201, 'ticker': 'KLAC', 'title': 'KLA CORP'},
#  '166': {'cik_str': 929869, 'ticker': 'RELX', 'title': 'RELX PLC'},
#  '167': {'cik_str': 713676,
#   'ticker': 'PNC',
#   'title': 'PNC FINANCIAL SERVICES GROUP, INC.'},
#  '168': {'cik_str': 1535527,
#   'ticker': 'CRWD',
#   'title': 'CrowdStrike Holdings, Inc.'},
#  '169': {'cik_str': 68505,
#   'ticker': 'MSI',
#   'title': 'Motorola Solutions, Inc.'},
#  '170': {'cik_str': 315293, 'ticker': 'AON', 'title': 'Aon plc'},
#  '171': {'cik_str': 1156375, 'ticker': 'CME', 'title': 'CME GROUP INC.'},
#  '172': {'cik_str': 883241, 'ticker': 'SNPS', 'title': 'SYNOPSYS INC'},
#  '173': {'cik_str': 1058090,
#   'ticker': 'CMG',
#   'title': 'CHIPOTLE MEXICAN GRILL INC'},
#  '174': {'cik_str': 948401,
#   'ticker': 'CFRUY',
#   'title': 'COMPAGNIE FINANCIERE RICHEMONT AG /FI'},
#  '175': {'cik_str': 49826,
#   'ticker': 'ITW',
#   'title': 'ILLINOIS TOOL WORKS INC'},
#  '176': {'cik_str': 1303523,
#   'ticker': 'BTI',
#   'title': 'British American Tobacco p.l.c.'},
#  '177': {'cik_str': 813672,
#   'ticker': 'CDNS',
#   'title': 'CADENCE DESIGN SYSTEMS INC'},
#  '178': {'cik_str': 40533, 'ticker': 'GD', 'title': 'GENERAL DYNAMICS CORP'},
#  '179': {'cik_str': 1555280, 'ticker': 'ZTS', 'title': 'Zoetis Inc.'},
#  '180': {'cik_str': 1001838,
#   'ticker': 'SCCO',
#   'title': 'SOUTHERN COPPER CORP/'},
#  '181': {'cik_str': 36104, 'ticker': 'USB', 'title': 'US BANCORP \\DE\\'},
#  '182': {'cik_str': 1648416, 'ticker': 'RACE', 'title': 'Ferrari N.V.'},
#  '183': {'cik_str': 1048286,
#   'ticker': 'MAR',
#   'title': 'MARRIOTT INTERNATIONAL INC /MD/'},
#  '184': {'cik_str': 927653, 'ticker': 'MCK', 'title': 'MCKESSON CORP'},
#  '185': {'cik_str': 21665, 'ticker': 'CL', 'title': 'COLGATE PALMOLIVE CO'},
#  '186': {'cik_str': 1835632,
#   'ticker': 'MRVL',
#   'title': 'Marvell Technology, Inc.'},
#  '187': {'cik_str': 313807, 'ticker': 'BP', 'title': 'BP PLC'},
#  '188': {'cik_str': 1381197,
#   'ticker': 'IBKR',
#   'title': 'Interactive Brokers Group, Inc.'},
#  '189': {'cik_str': 821189, 'ticker': 'EOG', 'title': 'EOG RESOURCES INC'},
#  '190': {'cik_str': 1679788,
#   'ticker': 'COIN',
#   'title': 'Coinbase Global, Inc.'},
#  '191': {'cik_str': 891478, 'ticker': 'SAN', 'title': 'Banco Santander, S.A.'},
#  '192': {'cik_str': 1075124,
#   'ticker': 'TRI',
#   'title': 'THOMSON REUTERS CORP /CAN/'},
#  '193': {'cik_str': 32604, 'ticker': 'EMR', 'title': 'EMERSON ELECTRIC CO'},
#  '194': {'cik_str': 1262039, 'ticker': 'FTNT', 'title': 'Fortinet, Inc.'},
#  '195': {'cik_str': 1133421,
#   'ticker': 'NOC',
#   'title': 'NORTHROP GRUMMAN CORP /DE/'},
#  '196': {'cik_str': 1048911, 'ticker': 'FDX', 'title': 'FEDEX CORP'},
#  '197': {'cik_str': 1442651,
#   'ticker': 'SHECY',
#   'title': 'Shin-Etsu Chemical Co., Ltd.'},
#  '198': {'cik_str': 66740, 'ticker': 'MMM', 'title': '3M CO'},
#  '199': {'cik_str': 1050446, 'ticker': 'MSTR', 'title': 'MICROSTRATEGY Inc'},
#  '200': {'cik_str': 1792789, 'ticker': 'DASH', 'title': 'DoorDash, Inc.'},
#  '201': {'cik_str': 1017413,
#   'ticker': 'CNQ',
#   'title': 'CANADIAN NATURAL RESOURCES LTD'},
#  '202': {'cik_str': 27419, 'ticker': 'TGT', 'title': 'TARGET CORP'},
#  '203': {'cik_str': 2969,
#   'ticker': 'APD',
#   'title': 'Air Products & Chemicals, Inc.'},
#  '204': {'cik_str': 927628,
#   'ticker': 'COF',
#   'title': 'CAPITAL ONE FINANCIAL CORP'},
#  '205': {'cik_str': 1260221, 'ticker': 'TDG', 'title': 'TransDigm Group INC'},
#  '206': {'cik_str': 898173,
#   'ticker': 'ORLY',
#   'title': 'O REILLY AUTOMOTIVE INC'},
#  '207': {'cik_str': 1868275,
#   'ticker': 'CEG',
#   'title': 'Constellation Energy Corp'},
#  '208': {'cik_str': 16875,
#   'ticker': 'CP',
#   'title': 'CANADIAN PACIFIC KANSAS CITY LTD/CN'},
#  '209': {'cik_str': 31462, 'ticker': 'ECL', 'title': 'ECOLAB INC.'},
#  '210': {'cik_str': 16868,
#   'ticker': 'CNI',
#   'title': 'CANADIAN NATIONAL RAILWAY CO'},
#  '211': {'cik_str': 1131399, 'ticker': 'GSK', 'title': 'GSK plc'},
#  '212': {'cik_str': 1327811, 'ticker': 'WDAY', 'title': 'Workday, Inc.'},
#  '213': {'cik_str': 927971,
#   'ticker': 'BMO',
#   'title': 'BANK OF MONTREAL /CAN/'},
#  '214': {'cik_str': 107263,
#   'ticker': 'WMB',
#   'title': 'WILLIAMS COMPANIES, INC.'},
#  '215': {'cik_str': 277948, 'ticker': 'CSX', 'title': 'CSX CORP'},
#  '216': {'cik_str': 1063761,
#   'ticker': 'SPG',
#   'title': 'SIMON PROPERTY GROUP INC /DE/'},
#  '217': {'cik_str': 1061219,
#   'ticker': 'EPD',
#   'title': 'ENTERPRISE PRODUCTS PARTNERS L.P.'},
#  '218': {'cik_str': 1691493, 'ticker': 'NU', 'title': 'Nu Holdings Ltd.'},
#  '219': {'cik_str': 9631, 'ticker': 'BNS', 'title': 'BANK OF NOVA SCOTIA'},
#  '220': {'cik_str': 849395, 'ticker': 'CRH', 'title': 'CRH PUBLIC LTD CO'},
#  '221': {'cik_str': 64803, 'ticker': 'CVS', 'title': 'CVS HEALTH Corp'},
#  '222': {'cik_str': 1783180, 'ticker': 'CARR', 'title': 'CARRIER GLOBAL Corp'},
#  '223': {'cik_str': 835403, 'ticker': 'DEO', 'title': 'DIAGEO PLC'},
#  '224': {'cik_str': 1140625, 'ticker': 'EQNR', 'title': 'EQUINOR ASA'},
#  '225': {'cik_str': 10795, 'ticker': 'BDX', 'title': 'BECTON DICKINSON & CO'},
#  '226': {'cik_str': 1060391,
#   'ticker': 'RSG',
#   'title': 'REPUBLIC SERVICES, INC.'},
#  '227': {'cik_str': 354190,
#   'ticker': 'AJG',
#   'title': 'Arthur J. Gallagher & Co.'},
#  '228': {'cik_str': 769397, 'ticker': 'ADSK', 'title': 'Autodesk, Inc.'},
#  '229': {'cik_str': 1039684, 'ticker': 'OKE', 'title': 'ONEOK INC /NEW/'},
#  '230': {'cik_str': 1443276, 'ticker': 'TOELY', 'title': 'Tokyo Electron LTD'},
#  '231': {'cik_str': 1947559,
#   'ticker': 'ANZGY',
#   'title': 'ANZ GROUP HOLDINGS LIMITED/ADR'},
#  '232': {'cik_str': 1467858, 'ticker': 'GM', 'title': 'General Motors Co'},
#  '233': {'cik_str': 1650372, 'ticker': 'TEAM', 'title': 'Atlassian Corp'},
#  '234': {'cik_str': 884887,
#   'ticker': 'RCL',
#   'title': 'ROYAL CARIBBEAN CRUISES LTD'},
#  '235': {'cik_str': 4977, 'ticker': 'AFL', 'title': 'AFLAC INC'},
#  '236': {'cik_str': 1222333, 'ticker': 'GLD', 'title': 'SPDR GOLD TRUST'},
#  '237': {'cik_str': 92230, 'ticker': 'TFC', 'title': 'TRUIST FINANCIAL CORP'},
#  '238': {'cik_str': 1335730,
#   'ticker': 'MFG',
#   'title': 'MIZUHO FINANCIAL GROUP INC'},
#  '239': {'cik_str': 831259, 'ticker': 'FCX', 'title': 'FREEPORT-MCMORAN INC'},
#  '240': {'cik_str': 1004315, 'ticker': 'NGG', 'title': 'NATIONAL GRID PLC'},
#  '241': {'cik_str': 87347,
#   'ticker': 'SLB',
#   'title': 'SCHLUMBERGER LIMITED/NV'},
#  '242': {'cik_str': 1297996,
#   'ticker': 'DLR',
#   'title': 'DIGITAL REALTY TRUST, INC.'},
#  '243': {'cik_str': 1585689,
#   'ticker': 'HLT',
#   'title': 'Hilton Worldwide Holdings Inc.'},
#  '244': {'cik_str': 1506307, 'ticker': 'KMI', 'title': 'KINDER MORGAN, INC.'},
#  '245': {'cik_str': 1045520,
#   'ticker': 'CM',
#   'title': 'CANADIAN IMPERIAL BANK OF COMMERCE /CAN/'},
#  '246': {'cik_str': 1067318, 'ticker': 'MBGYY', 'title': 'DAIMLER AG'},
#  '247': {'cik_str': 702165, 'ticker': 'NSC', 'title': 'NORFOLK SOUTHERN CORP'},
#  '248': {'cik_str': 1276187, 'ticker': 'ET', 'title': 'Energy Transfer LP'},
#  '249': {'cik_str': 86312,
#   'ticker': 'TRV',
#   'title': 'TRAVELERS COMPANIES, INC.'},
#  '250': {'cik_str': 882835,
#   'ticker': 'ROP',
#   'title': 'ROPER TECHNOLOGIES INC'},
#  '251': {'cik_str': 75362, 'ticker': 'PCAR', 'title': 'PACCAR INC'},
#  '252': {'cik_str': 1393311, 'ticker': 'PSA', 'title': 'Public Storage'},
#  '253': {'cik_str': 1671933, 'ticker': 'TTD', 'title': 'Trade Desk, Inc.'},
#  '254': {'cik_str': 1524684, 'ticker': 'GLNCY', 'title': 'Glencore plc/ADR'},
#  '255': {'cik_str': 1549802, 'ticker': 'JD', 'title': 'JD.com, Inc.'},
#  '256': {'cik_str': 1703399, 'ticker': 'SE', 'title': 'Sea Ltd'},
#  '257': {'cik_str': 1032208, 'ticker': 'SRE', 'title': 'SEMPRA'},
#  '258': {'cik_str': 1099219, 'ticker': 'MET', 'title': 'METLIFE INC'},
#  '259': {'cik_str': 1086888,
#   'ticker': 'MFC',
#   'title': 'MANULIFE FINANCIAL CORP'},
#  '260': {'cik_str': 277135, 'ticker': 'GWW', 'title': 'W.W. GRAINGER, INC.'},
#  '261': {'cik_str': 1390777,
#   'ticker': 'BK',
#   'title': 'Bank of New York Mellon Corp'},
#  '262': {'cik_str': 842180,
#   'ticker': 'BBVA',
#   'title': 'BANCO BILBAO VIZCAYA ARGENTARIA, S.A.'},
#  '263': {'cik_str': 833444,
#   'ticker': 'JCI',
#   'title': 'Johnson Controls International plc'},
#  '264': {'cik_str': 1413447,
#   'ticker': 'NXPI',
#   'title': 'NXP Semiconductors N.V.'},
#  '265': {'cik_str': 1132597,
#   'ticker': 'ITUB',
#   'title': 'Itau Unibanco Holding S.A.'},
#  '266': {'cik_str': 1091667,
#   'ticker': 'CHTR',
#   'title': 'CHARTER COMMUNICATIONS, INC. /MO/'},
#  '267': {'cik_str': 814547, 'ticker': 'FICO', 'title': 'FAIR ISAAC CORP'},
#  '268': {'cik_str': 1067701, 'ticker': 'URI', 'title': 'UNITED RENTALS, INC.'},
#  '269': {'cik_str': 1110646, 'ticker': 'NTES', 'title': 'NetEase, Inc.'},
#  '270': {'cik_str': 820027,
#   'ticker': 'AMP',
#   'title': 'AMERIPRISE FINANCIAL INC'},
#  '271': {'cik_str': 1004980, 'ticker': 'PCG', 'title': 'PG&E Corp'},
#  '272': {'cik_str': 900075, 'ticker': 'CPRT', 'title': 'COPART INC'},
#  '273': {'cik_str': 1547873,
#   'ticker': 'PTCAY',
#   'title': 'PT Chandra Asri Petrochemical Tbk/ADR'},
#  '274': {'cik_str': 1534701, 'ticker': 'PSX', 'title': 'Phillips 66'},
#  '275': {'cik_str': 866787, 'ticker': 'AZO', 'title': 'AUTOZONE INC'},
#  '276': {'cik_str': 882184, 'ticker': 'DHI', 'title': 'HORTON D R INC /DE/'},
#  '277': {'cik_str': 1176948,
#   'ticker': 'ARES',
#   'title': 'Ares Management Corp'},
#  '278': {'cik_str': 899051, 'ticker': 'ALL', 'title': 'ALLSTATE CORP'},
#  '279': {'cik_str': 1539838,
#   'ticker': 'FANG',
#   'title': 'Diamondback Energy, Inc.'},
#  '280': {'cik_str': 723531, 'ticker': 'PAYX', 'title': 'PAYCHEX INC'},
#  '281': {'cik_str': 865752,
#   'ticker': 'MNST',
#   'title': 'Monster Beverage Corp'},
#  '282': {'cik_str': 30554, 'ticker': 'CTA-PA', 'title': 'EIDP, Inc.'},
#  '283': {'cik_str': 1512673, 'ticker': 'SQ', 'title': 'Block, Inc.'},
#  '284': {'cik_str': 4904,
#   'ticker': 'AEP',
#   'title': 'AMERICAN ELECTRIC POWER CO INC'},
#  '285': {'cik_str': 311337, 'ticker': 'SU', 'title': 'SUNCOR ENERGY INC'},
#  '286': {'cik_str': 1232384, 'ticker': 'TRP', 'title': 'TC ENERGY CORP'},
#  '287': {'cik_str': 1510295,
#   'ticker': 'MPC',
#   'title': 'Marathon Petroleum Corp'},
#  '288': {'cik_str': 895564,
#   'ticker': 'BAESY',
#   'title': 'BAE SYSTEMS PLC /FI/'},
#  '289': {'cik_str': 26172, 'ticker': 'CMI', 'title': 'CUMMINS INC'},
#  '290': {'cik_str': 1039765, 'ticker': 'ING', 'title': 'ING GROEP NV'},
#  '291': {'cik_str': 1588489,
#   'ticker': 'GBTC',
#   'title': 'Grayscale Bitcoin Trust ETF'},
#  '292': {'cik_str': 726728, 'ticker': 'O', 'title': 'REALTY INCOME CORP'},
#  '293': {'cik_str': 312069, 'ticker': 'BCS', 'title': 'BARCLAYS PLC'},
#  '294': {'cik_str': 715957, 'ticker': 'D', 'title': 'DOMINION ENERGY, INC'},
#  '295': {'cik_str': 1552000, 'ticker': 'MPLX', 'title': 'MPLX LP'},
#  '296': {'cik_str': 1692819, 'ticker': 'VST', 'title': 'Vistra Corp.'},
#  '297': {'cik_str': 1050915,
#   'ticker': 'PWR',
#   'title': 'QUANTA SERVICES, INC.'},
#  '298': {'cik_str': 1012037,
#   'ticker': 'CODYY',
#   'title': 'COMPAGNIE DE SAINT GOBAIN'},
#  '299': {'cik_str': 1318220,
#   'ticker': 'WCN',
#   'title': 'Waste Connections, Inc.'},
#  '300': {'cik_str': 1136893,
#   'ticker': 'FIS',
#   'title': 'Fidelity National Information Services, Inc.'},
#  '301': {'cik_str': 5272,
#   'ticker': 'AIG',
#   'title': 'AMERICAN INTERNATIONAL GROUP, INC.'},
#  '302': {'cik_str': 3570, 'ticker': 'LNG', 'title': 'Cheniere Energy, Inc.'},
#  '303': {'cik_str': 1635327,
#   'ticker': 'FLUT',
#   'title': 'Flutter Entertainment plc'},
#  '304': {'cik_str': 1278680, 'ticker': 'IAU', 'title': 'ISHARES GOLD TRUST'},
#  '305': {'cik_str': 1140859, 'ticker': 'COR', 'title': 'Cencora, Inc.'},
#  '306': {'cik_str': 815556, 'ticker': 'FAST', 'title': 'FASTENAL CO'},
#  '307': {'cik_str': 797468,
#   'ticker': 'OXY',
#   'title': 'OCCIDENTAL PETROLEUM CORP /DE/'},
#  '308': {'cik_str': 1129137,
#   'ticker': 'AMX',
#   'title': 'AMERICA MOVIL SAB DE CV/'},
#  '309': {'cik_str': 1408198, 'ticker': 'MSCI', 'title': 'MSCI Inc.'},
#  '310': {'cik_str': 202058,
#   'ticker': 'LHX',
#   'title': 'L3HARRIS TECHNOLOGIES, INC. /DE/'},
#  '311': {'cik_str': 745732, 'ticker': 'ROST', 'title': 'ROSS STORES, INC.'},
#  '312': {'cik_str': 1002242, 'ticker': 'E', 'title': 'ENI SPA'},
#  '313': {'cik_str': 1164727, 'ticker': 'NEM', 'title': 'NEWMONT Corp /DE/'},
#  '314': {'cik_str': 878927,
#   'ticker': 'ODFL',
#   'title': 'OLD DOMINION FREIGHT LINE, INC.'},
#  '315': {'cik_str': 1944048, 'ticker': 'KVUE', 'title': 'Kenvue Inc.'},
#  '316': {'cik_str': 1069183,
#   'ticker': 'AXON',
#   'title': 'AXON ENTERPRISE, INC.'},
#  '317': {'cik_str': 4281, 'ticker': 'HWM', 'title': 'Howmet Aerospace Inc.'},
#  '318': {'cik_str': 920760, 'ticker': 'LEN', 'title': 'LENNAR CORP /NEW/'},
#  '319': {'cik_str': 1137774,
#   'ticker': 'PRU',
#   'title': 'PRUDENTIAL FINANCIAL INC'},
#  '320': {'cik_str': 1120193, 'ticker': 'NDAQ', 'title': 'NASDAQ, INC.'},
#  '321': {'cik_str': 55785, 'ticker': 'KMB', 'title': 'KIMBERLY CLARK CORP'},
#  '322': {'cik_str': 1051470, 'ticker': 'CCI', 'title': 'CROWN CASTLE INC.'},
#  '323': {'cik_str': 1674101, 'ticker': 'VRT', 'title': 'Vertiv Holdings Co'},
#  '324': {'cik_str': 4447, 'ticker': 'HES', 'title': 'HESS CORP'},
#  '325': {'cik_str': 1037868, 'ticker': 'AME', 'title': 'AMETEK INC/'},
#  '326': {'cik_str': 1385157, 'ticker': 'TEL', 'title': 'TE Connectivity plc'},
#  '327': {'cik_str': 37996, 'ticker': 'F', 'title': 'FORD MOTOR CO'},
#  '328': {'cik_str': 1035002,
#   'ticker': 'VLO',
#   'title': 'VALERO ENERGY CORP/TX'},
#  '329': {'cik_str': 1393612,
#   'ticker': 'DFS',
#   'title': 'Discover Financial Services'},
#  '330': {'cik_str': 788784,
#   'ticker': 'PEG',
#   'title': 'PUBLIC SERVICE ENTERPRISE GROUP INC'},
#  '331': {'cik_str': 1834584, 'ticker': 'CPNG', 'title': 'Coupang, Inc.'},
#  '332': {'cik_str': 1446250,
#   'ticker': 'BMWKY',
#   'title': 'Bayerische Motoren Werke AG/ADR'},
#  '333': {'cik_str': 16918,
#   'ticker': 'STZ',
#   'title': 'CONSTELLATION BRANDS, INC.'},
#  '334': {'cik_str': 1395064,
#   'ticker': 'TAK',
#   'title': 'TAKEDA PHARMACEUTICAL CO LTD'},
#  '335': {'cik_str': 1160106,
#   'ticker': 'LYG',
#   'title': 'Lloyds Banking Group plc'},
#  '336': {'cik_str': 1418135,
#   'ticker': 'KDP',
#   'title': 'Keurig Dr Pepper Inc.'},
#  '337': {'cik_str': 1279967,
#   'ticker': 'CRARY',
#   'title': 'CREDIT AGRICOLE S A'},
#  '338': {'cik_str': 1561550, 'ticker': 'DDOG', 'title': 'Datadog, Inc.'},
#  '339': {'cik_str': 1446598, 'ticker': 'DNZOY', 'title': 'Denso Corp'},
#  '340': {'cik_str': 1167379, 'ticker': 'ALC', 'title': 'ALCON INC'},
#  '341': {'cik_str': 1535628, 'ticker': 'CAIXY', 'title': 'CaixaBank/ADR'},
#  '342': {'cik_str': 712515, 'ticker': 'EA', 'title': 'ELECTRONIC ARTS INC.'},
#  '343': {'cik_str': 1900304, 'ticker': 'HLN', 'title': 'Haleon plc'},
#  '344': {'cik_str': 1389170,
#   'ticker': 'TRGP',
#   'title': 'Targa Resources Corp.'},
#  '345': {'cik_str': 917851, 'ticker': 'VALE', 'title': 'Vale S.A.'},
#  '346': {'cik_str': 1158838, 'ticker': 'ATEYY', 'title': 'ADVANTEST CORP'},
#  '347': {'cik_str': 1701605, 'ticker': 'BKR', 'title': 'Baker Hughes Co'},
#  '348': {'cik_str': 56873, 'ticker': 'KR', 'title': 'KROGER CO'},
#  '349': {'cik_str': 1640147, 'ticker': 'SNOW', 'title': 'Snowflake Inc.'},
#  '350': {'cik_str': 844150, 'ticker': 'NWG', 'title': 'NatWest Group plc'},
#  '351': {'cik_str': 27904, 'ticker': 'DAL', 'title': 'DELTA AIR LINES, INC.'},
#  '352': {'cik_str': 1699150, 'ticker': 'IR', 'title': 'Ingersoll Rand Inc.'},
#  '353': {'cik_str': 1359519,
#   'ticker': 'SVNDY',
#   'title': 'SEVEN & I HOLDINGS CO LTD'},
#  '354': {'cik_str': 749251, 'ticker': 'IT', 'title': 'GARTNER INC'},
#  '355': {'cik_str': 1121788, 'ticker': 'GRMN', 'title': 'GARMIN LTD'},
#  '356': {'cik_str': 715153, 'ticker': 'HMC', 'title': 'HONDA MOTOR CO LTD'},
#  '357': {'cik_str': 2011641,
#   'ticker': 'FERG',
#   'title': 'Ferguson Enterprises Inc. /DE/'},
#  '358': {'cik_str': 1138118, 'ticker': 'CBRE', 'title': 'CBRE GROUP, INC.'},
#  '359': {'cik_str': 24741, 'ticker': 'GLW', 'title': 'CORNING INC /NY'},
#  '360': {'cik_str': 72903, 'ticker': 'XEL', 'title': 'XCEL ENERGY INC'},
#  '361': {'cik_str': 1442145,
#   'ticker': 'VRSK',
#   'title': 'Verisk Analytics, Inc.'},
#  '362': {'cik_str': 1099800,
#   'ticker': 'EW',
#   'title': 'Edwards Lifesciences Corp'},
#  '363': {'cik_str': 1397187,
#   'ticker': 'LULU',
#   'title': 'lululemon athletica inc.'},
#  '364': {'cik_str': 1781335, 'ticker': 'OTIS', 'title': 'Otis Worldwide Corp'},
#  '365': {'cik_str': 1269238, 'ticker': 'TCOM', 'title': 'Trip.com Group Ltd'},
#  '366': {'cik_str': 1109357, 'ticker': 'EXC', 'title': 'EXELON CORP'},
#  '367': {'cik_str': 49938, 'ticker': 'IMO', 'title': 'IMPERIAL OIL LTD'},
#  '368': {'cik_str': 1545460,
#   'ticker': 'OLCLY',
#   'title': 'Oriental Land Co., Ltd./ADR'},
#  '369': {'cik_str': 2809, 'ticker': 'AEM', 'title': 'AGNICO EAGLE MINES LTD'},
#  '370': {'cik_str': 1058290,
#   'ticker': 'CTSH',
#   'title': 'COGNIZANT TECHNOLOGY SOLUTIONS CORP'},
#  '371': {'cik_str': 1605484, 'ticker': 'STLA', 'title': 'Stellantis N.V.'},
#  '372': {'cik_str': 1755672, 'ticker': 'CTVA', 'title': 'Corteva, Inc.'},
#  '373': {'cik_str': 947484,
#   'ticker': 'ACGL',
#   'title': 'ARCH CAPITAL GROUP LTD.'},
#  '374': {'cik_str': 1637459, 'ticker': 'KHC', 'title': 'Kraft Heinz Co'},
#  '375': {'cik_str': 861967,
#   'ticker': 'WTKWY',
#   'title': 'WOLTERS KLUWER N V /FI'},
#  '376': {'cik_str': 1041061, 'ticker': 'YUM', 'title': 'YUM BRANDS INC'},
#  '377': {'cik_str': 1461748,
#   'ticker': 'PPERY',
#   'title': 'PT Bank Mandiri (Persero) Tbk / ADR'},
#  '378': {'cik_str': 1932393,
#   'ticker': 'GEHC',
#   'title': 'GE HealthCare Technologies Inc.'},
#  '379': {'cik_str': 96021, 'ticker': 'SYY', 'title': 'SYSCO CORP'},
#  '380': {'cik_str': 1396009, 'ticker': 'VMC', 'title': 'Vulcan Materials CO'},
#  '381': {'cik_str': 1090872,
#   'ticker': 'A',
#   'title': 'AGILENT TECHNOLOGIES, INC.'},
#  '382': {'cik_str': 1289490,
#   'ticker': 'EXR',
#   'title': 'Extra Space Storage Inc.'},
#  '383': {'cik_str': 36270, 'ticker': 'MTB', 'title': 'M&T BANK CORP'},
#  '384': {'cik_str': 916076,
#   'ticker': 'MLM',
#   'title': 'MARTIN MARIETTA MATERIALS INC'},
#  '385': {'cik_str': 47217, 'ticker': 'HPQ', 'title': 'HP INC'},
#  '386': {'cik_str': 1041130,
#   'ticker': 'DIA',
#   'title': 'SPDR DOW JONES INDUSTRIAL AVERAGE ETF TRUST'},
#  '387': {'cik_str': 1123799, 'ticker': 'WIT', 'title': 'WIPRO LTD'},
#  '388': {'cik_str': 1650107,
#   'ticker': 'CCEP',
#   'title': 'COCA-COLA EUROPACIFIC PARTNERS plc'},
#  '389': {'cik_str': 1478242, 'ticker': 'IQV', 'title': 'IQVIA HOLDINGS INC.'},
#  '390': {'cik_str': 40704, 'ticker': 'GIS', 'title': 'GENERAL MILLS INC'},
#  '391': {'cik_str': 47111, 'ticker': 'HSY', 'title': 'HERSHEY CO'},
#  '392': {'cik_str': 1300514, 'ticker': 'LVS', 'title': 'LAS VEGAS SANDS CORP'},
#  '393': {'cik_str': 1446519,
#   'ticker': 'DKILY',
#   'title': 'Daikin Industries Ltd'},
#  '394': {'cik_str': 1404655, 'ticker': 'HUBS', 'title': 'HUBSPOT INC'},
#  '395': {'cik_str': 1393052, 'ticker': 'VEEV', 'title': 'VEEVA SYSTEMS INC'},
#  '396': {'cik_str': 1565025, 'ticker': 'ABEV', 'title': 'AMBEV S.A.'},
#  '397': {'cik_str': 1097362,
#   'ticker': 'SLF',
#   'title': 'SUN LIFE FINANCIAL INC'},
#  '398': {'cik_str': 73309, 'ticker': 'NUE', 'title': 'NUCOR CORP'},
#  '399': {'cik_str': 874716,
#   'ticker': 'IDXX',
#   'title': 'IDEXX LABORATORIES INC /DE'},
#  '400': {'cik_str': 943819, 'ticker': 'RMD', 'title': 'RESMED INC'},
#  '401': {'cik_str': 1697862, 'ticker': 'ARGX', 'title': 'ARGENX SE'},
#  '402': {'cik_str': 1666700,
#   'ticker': 'DD',
#   'title': 'DuPont de Nemours, Inc.'},
#  '403': {'cik_str': 874766,
#   'ticker': 'HIG',
#   'title': 'HARTFORD FINANCIAL SERVICES GROUP, INC.'},
#  '404': {'cik_str': 827054,
#   'ticker': 'MCHP',
#   'title': 'MICROCHIP TECHNOLOGY INC'},
#  '405': {'cik_str': 1315098, 'ticker': 'RBLX', 'title': 'Roblox Corp'},
#  '406': {'cik_str': 1020569, 'ticker': 'IRM', 'title': 'IRON MOUNTAIN INC'},
#  '407': {'cik_str': 943452,
#   'ticker': 'WAB',
#   'title': 'WESTINGHOUSE AIR BRAKE TECHNOLOGIES CORP'},
#  '408': {'cik_str': 1823945,
#   'ticker': 'OWL',
#   'title': 'BLUE OWL CAPITAL INC.'},
#  '409': {'cik_str': 1471055,
#   'ticker': 'BSBR',
#   'title': 'Banco Santander (Brasil) S.A.'},
#  '410': {'cik_str': 1047862,
#   'ticker': 'ED',
#   'title': 'CONSOLIDATED EDISON INC'},
#  '411': {'cik_str': 1705696,
#   'ticker': 'VICI',
#   'title': 'VICI PROPERTIES INC.'},
#  '412': {'cik_str': 49071, 'ticker': 'HUM', 'title': 'HUMANA INC'},
#  '413': {'cik_str': 1159508,
#   'ticker': 'DB',
#   'title': 'DEUTSCHE BANK AKTIENGESELLSCHAFT'},
#  '414': {'cik_str': 720005,
#   'ticker': 'RJF',
#   'title': 'RAYMOND JAMES FINANCIAL INC'},
#  '415': {'cik_str': 915912,
#   'ticker': 'AVB',
#   'title': 'AVALONBAY COMMUNITIES INC'},
#  '416': {'cik_str': 1024478,
#   'ticker': 'ROK',
#   'title': 'ROCKWELL AUTOMATION, INC'},
#  '417': {'cik_str': 815097, 'ticker': 'CCL', 'title': 'CARNIVAL CORP'},
#  '418': {'cik_str': 936958,
#   'ticker': 'MDY',
#   'title': 'SPDR S&P MIDCAP 400 ETF TRUST'},
#  '419': {'cik_str': 46619, 'ticker': 'HEI', 'title': 'HEICO CORP'},
#  '420': {'cik_str': 827052, 'ticker': 'EIX', 'title': 'EDISON INTERNATIONAL'},
#  '421': {'cik_str': 850918,
#   'ticker': 'GWLIF',
#   'title': 'GREAT-WEST LIFECO INC.'},
#  '422': {'cik_str': 65984, 'ticker': 'ETR', 'title': 'ENTERGY CORP /DE/'},
#  '423': {'cik_str': 1700171, 'ticker': 'ANYYY', 'title': 'Aena S.A./ADR'},
#  '424': {'cik_str': 35527, 'ticker': 'FITB', 'title': 'FIFTH THIRD BANCORP'},
#  '425': {'cik_str': 1140536,
#   'ticker': 'WTW',
#   'title': 'WILLIS TOWERS WATSON PLC'},
#  '426': {'cik_str': 79282, 'ticker': 'BRO', 'title': 'BROWN & BROWN, INC.'},
#  '427': {'cik_str': 915191,
#   'ticker': 'FRFHF',
#   'title': 'FAIRFAX FINANCIAL HOLDINGS LTD/ CAN'},
#  '428': {'cik_str': 1450468,
#   'ticker': 'MRAAY',
#   'title': 'Murata Manufacturing Co., Ltd./ADR'},
#  '429': {'cik_str': 946581,
#   'ticker': 'TTWO',
#   'title': 'TAKE TWO INTERACTIVE SOFTWARE INC'},
#  '430': {'cik_str': 1811074,
#   'ticker': 'TPL',
#   'title': 'Texas Pacific Land Corp'},
#  '431': {'cik_str': 1178670,
#   'ticker': 'ALNY',
#   'title': 'ALNYLAM PHARMACEUTICALS, INC.'},
#  '432': {'cik_str': 1751788, 'ticker': 'DOW', 'title': 'DOW INC.'},
#  '433': {'cik_str': 33185, 'ticker': 'EFX', 'title': 'EQUIFAX INC'},
#  '434': {'cik_str': 783325,
#   'ticker': 'WEC',
#   'title': 'WEC ENERGY GROUP, INC.'},
#  '435': {'cik_str': 1618756,
#   'ticker': 'QSR',
#   'title': 'Restaurant Brands International Inc.'},
#  '436': {'cik_str': 1713683, 'ticker': 'ZS', 'title': 'Zscaler, Inc.'},
#  '437': {'cik_str': 1477333, 'ticker': 'NET', 'title': 'Cloudflare, Inc.'},
#  '438': {'cik_str': 798941,
#   'ticker': 'FCNCA',
#   'title': 'FIRST CITIZENS BANCSHARES INC /DE/'},
#  '439': {'cik_str': 1093557, 'ticker': 'DXCM', 'title': 'DEXCOM INC'},
#  '440': {'cik_str': 100517,
#   'ticker': 'UAL',
#   'title': 'United Airlines Holdings, Inc.'},
#  '441': {'cik_str': 1335258,
#   'ticker': 'LYV',
#   'title': 'Live Nation Entertainment, Inc.'},
#  '442': {'cik_str': 1524472, 'ticker': 'XYL', 'title': 'Xylem Inc.'},
#  '443': {'cik_str': 916365,
#   'ticker': 'TSCO',
#   'title': 'TRACTOR SUPPLY CO /DE/'},
#  '444': {'cik_str': 1123360, 'ticker': 'GPN', 'title': 'GLOBAL PAYMENTS INC'},
#  '445': {'cik_str': 1132924,
#   'ticker': 'CHT',
#   'title': 'CHUNGHWA TELECOM CO LTD'},
#  '446': {'cik_str': 1057352, 'ticker': 'CSGP', 'title': 'COSTAR GROUP, INC.'},
#  '447': {'cik_str': 1329099, 'ticker': 'BIDU', 'title': 'Baidu, Inc.'},
#  '448': {'cik_str': 1065088, 'ticker': 'EBAY', 'title': 'EBAY INC'},
#  '449': {'cik_str': 756894, 'ticker': 'GOLD', 'title': 'BARRICK GOLD CORP'},
#  '450': {'cik_str': 844551,
#   'ticker': 'WDS',
#   'title': 'WOODSIDE ENERGY GROUP LTD'},
#  '451': {'cik_str': 1013462, 'ticker': 'ANSS', 'title': 'ANSYS INC'},
#  '452': {'cik_str': 1671750,
#   'ticker': 'DSCSY',
#   'title': 'Disco Corporation/ADR'},
#  '453': {'cik_str': 1071739, 'ticker': 'CNC', 'title': 'CENTENE CORP'},
#  '454': {'cik_str': 721371, 'ticker': 'CAH', 'title': 'CARDINAL HEALTH INC'},
#  '455': {'cik_str': 906107, 'ticker': 'EQR', 'title': 'EQUITY RESIDENTIAL'},
#  '456': {'cik_str': 1445465, 'ticker': 'PPRUY', 'title': 'Kering'},
#  '457': {'cik_str': 1475260, 'ticker': 'CVE', 'title': 'CENOVUS ENERGY INC.'},
#  '458': {'cik_str': 79879, 'ticker': 'PPG', 'title': 'PPG INDUSTRIES INC'},
#  '459': {'cik_str': 1758730, 'ticker': 'TW', 'title': 'Tradeweb Markets Inc.'},
#  '460': {'cik_str': 1783879,
#   'ticker': 'HOOD',
#   'title': 'Robinhood Markets, Inc.'},
#  '461': {'cik_str': 1690820, 'ticker': 'CVNA', 'title': 'CARVANA CO.'},
#  '462': {'cik_str': 1125259, 'ticker': 'CUK', 'title': 'CARNIVAL PLC'},
#  '463': {'cik_str': 55067, 'ticker': 'K', 'title': 'KELLANOVA'},
#  '464': {'cik_str': 93751, 'ticker': 'STT', 'title': 'STATE STREET CORP'},
#  '465': {'cik_str': 1468522, 'ticker': 'FER', 'title': 'Ferrovial SE'},
#  '466': {'cik_str': 906163, 'ticker': 'NVR', 'title': 'NVR INC'},
#  '467': {'cik_str': 29905, 'ticker': 'DOV', 'title': 'DOVER Corp'},
#  '468': {'cik_str': 1642896, 'ticker': 'IOT', 'title': 'Samsara Inc.'},
#  '469': {'cik_str': 1097864, 'ticker': 'ON', 'title': 'ON SEMICONDUCTOR CORP'},
#  '470': {'cik_str': 1021020,
#   'ticker': 'OEZVY',
#   'title': 'OSTERREICHISCHE ELEKTRIZITATSWIRTSCHAFTS /FI'},
#  '471': {'cik_str': 1280452,
#   'ticker': 'MPWR',
#   'title': 'MONOLITHIC POWER SYSTEMS INC'},
#  '472': {'cik_str': 1645590,
#   'ticker': 'HPE',
#   'title': 'Hewlett Packard Enterprise Co'},
#  '473': {'cik_str': 1805284,
#   'ticker': 'RKT',
#   'title': 'Rocket Companies, Inc.'},
#  '474': {'cik_str': 1489393,
#   'ticker': 'LYB',
#   'title': 'LyondellBasell Industries N.V.'},
#  '475': {'cik_str': 717826,
#   'ticker': 'ERIC',
#   'title': 'ERICSSON LM TELEPHONE CO'},
#  '476': {'cik_str': 1131345, 'ticker': 'NVZMY', 'title': 'NOVOZYMES AS/FI'},
#  '477': {'cik_str': 1323404,
#   'ticker': 'WPM',
#   'title': 'Wheaton Precious Metals Corp.'},
#  '478': {'cik_str': 740260, 'ticker': 'VTR', 'title': 'Ventas, Inc.'},
#  '479': {'cik_str': 313927,
#   'ticker': 'CHD',
#   'title': 'CHURCH & DWIGHT CO INC /DE/'},
#  '480': {'cik_str': 910521, 'ticker': 'DECK', 'title': 'DECKERS OUTDOOR CORP'},
#  '481': {'cik_str': 2005951, 'ticker': 'SW', 'title': 'Smurfit Westrock plc'},
#  '482': {'cik_str': 1383312,
#   'ticker': 'BR',
#   'title': 'BROADRIDGE FINANCIAL SOLUTIONS, INC.'},
#  '483': {'cik_str': 822416, 'ticker': 'PHM', 'title': 'PULTEGROUP INC/MI/'},
#  '484': {'cik_str': 1113169,
#   'ticker': 'TROW',
#   'title': 'PRICE T ROWE GROUP INC'},
#  '485': {'cik_str': 45012, 'ticker': 'HAL', 'title': 'HALLIBURTON CO'},
#  '486': {'cik_str': 1410636,
#   'ticker': 'AWK',
#   'title': 'American Water Works Company, Inc.'},
#  '487': {'cik_str': 1601046,
#   'ticker': 'KEYS',
#   'title': 'Keysight Technologies, Inc.'},
#  '488': {'cik_str': 1659166, 'ticker': 'FTV', 'title': 'Fortive Corp'},
#  '489': {'cik_str': 1050952, 'ticker': 'PUBGY', 'title': 'PUBLICIS GROUPE SA'},
#  '490': {'cik_str': 800365,
#   'ticker': 'FUJIY',
#   'title': 'FUJI PHOTO FILM CO LTD /FI'},
#  '491': {'cik_str': 7084,
#   'ticker': 'ADM',
#   'title': 'Archer-Daniels-Midland Co'},
#  '492': {'cik_str': 1609711, 'ticker': 'GDDY', 'title': 'GoDaddy Inc.'},
#  '493': {'cik_str': 1383650,
#   'ticker': 'CQP',
#   'title': 'Cheniere Energy Partners, L.P.'},
#  '494': {'cik_str': 860731,
#   'ticker': 'TYL',
#   'title': 'TYLER TECHNOLOGIES INC'},
#  '495': {'cik_str': 33213, 'ticker': 'EQT', 'title': 'EQT Corp'},
#  '496': {'cik_str': 49196,
#   'ticker': 'HBAN',
#   'title': 'HUNTINGTON BANCSHARES INC /MD/'},
#  '497': {'cik_str': 1175454, 'ticker': 'CPAY', 'title': 'CORPAY, INC.'},
#  '498': {'cik_str': 1967680, 'ticker': 'VLTO', 'title': 'Veralto Corp'},
#  '499': {'cik_str': 1601712, 'ticker': 'SYF', 'title': 'Synchrony Financial'},
#  '500': {'cik_str': 814052, 'ticker': 'TEF', 'title': 'TELEFONICA S A'},
#  '501': {'cik_str': 1446705, 'ticker': 'NTDTY', 'title': 'NTT Data Corp'},
#  '502': {'cik_str': 1090012, 'ticker': 'DVN', 'title': 'DEVON ENERGY CORP/DE'},
#  '503': {'cik_str': 1037646,
#   'ticker': 'MTD',
#   'title': 'METTLER TOLEDO INTERNATIONAL INC/'},
#  '504': {'cik_str': 1585521,
#   'ticker': 'ZM',
#   'title': 'Zoom Video Communications, Inc.'},
#  '505': {'cik_str': 922224, 'ticker': 'PPL', 'title': 'PPL Corp'},
#  '506': {'cik_str': 936340, 'ticker': 'DTE', 'title': 'DTE ENERGY CO'},
#  '507': {'cik_str': 718940, 'ticker': 'BCE', 'title': 'BCE INC'},
#  '508': {'cik_str': 1070304, 'ticker': 'IX', 'title': 'ORIX CORP'},
#  '509': {'cik_str': 1446596, 'ticker': 'FANUY', 'title': 'Fanuc Ltd'},
#  '510': {'cik_str': 313216,
#   'ticker': 'PHG',
#   'title': 'KONINKLIJKE PHILIPS NV'},
#  '511': {'cik_str': 1038683,
#   'ticker': 'RYAAY',
#   'title': 'RYANAIR HOLDINGS PLC'},
#  '512': {'cik_str': 1445930,
#   'ticker': 'KB',
#   'title': 'KB Financial Group Inc.'},
#  '513': {'cik_str': 1002910, 'ticker': 'AEE', 'title': 'AMEREN CORP'},
#  '514': {'cik_str': 1061574, 'ticker': 'GIB', 'title': 'CGI INC'},
#  '515': {'cik_str': 924613, 'ticker': 'NOK', 'title': 'NOKIA CORP'},
#  '516': {'cik_str': 84839, 'ticker': 'ROL', 'title': 'ROLLINS INC'},
#  '517': {'cik_str': 1809587, 'ticker': 'BEKE', 'title': 'KE Holdings Inc.'},
#  '518': {'cik_str': 1546066,
#   'ticker': 'PBA',
#   'title': 'PEMBINA PIPELINE CORP'},
#  '519': {'cik_str': 1002047, 'ticker': 'NTAP', 'title': 'NetApp, Inc.'},
#  '520': {'cik_str': 1160330, 'ticker': 'BBD', 'title': 'BANK BRADESCO'},
#  '521': {'cik_str': 1281761,
#   'ticker': 'RF',
#   'title': 'REGIONS FINANCIAL CORP'},
#  '522': {'cik_str': 1031296, 'ticker': 'FE', 'title': 'FIRSTENERGY CORP'},
#  '523': {'cik_str': 1791706, 'ticker': 'LI', 'title': 'Li Auto Inc.'},
#  '524': {'cik_str': 20286,
#   'ticker': 'CINF',
#   'title': 'CINCINNATI FINANCIAL CORP'},
#  '525': {'cik_str': 48898, 'ticker': 'HUBB', 'title': 'HUBBELL INC'},
#  '526': {'cik_str': 1034054,
#   'ticker': 'SBAC',
#   'title': 'SBA COMMUNICATIONS CORP'},
#  '527': {'cik_str': 1776985, 'ticker': 'BNTX', 'title': 'BioNTech SE'},
#  '528': {'cik_str': 1402057, 'ticker': 'CDW', 'title': 'CDW Corp'},
#  '529': {'cik_str': 1937926,
#   'ticker': 'BAM',
#   'title': 'Brookfield Asset Management Ltd.'},
#  '530': {'cik_str': 875045, 'ticker': 'BIIB', 'title': 'BIOGEN INC.'},
#  '531': {'cik_str': 1397911,
#   'ticker': 'LPLA',
#   'title': 'LPL Financial Holdings Inc.'},
#  '532': {'cik_str': 1880661, 'ticker': 'TPG', 'title': 'TPG Inc.'},
#  '533': {'cik_str': 1009001, 'ticker': 'CCJ', 'title': 'CAMECO CORP'},
#  '534': {'cik_str': 1764757, 'ticker': 'DIDIY', 'title': 'DiDi Global Inc.'},
#  '535': {'cik_str': 1650164, 'ticker': 'TOST', 'title': 'Toast, Inc.'},
#  '536': {'cik_str': 100493, 'ticker': 'TSN', 'title': 'TYSON FOODS, INC.'},
#  '537': {'cik_str': 1324424, 'ticker': 'EXPE', 'title': 'Expedia Group, Inc.'},
#  '538': {'cik_str': 105634, 'ticker': 'EME', 'title': 'EMCOR Group, Inc.'},
#  '539': {'cik_str': 886986, 'ticker': 'TECK', 'title': 'TECK RESOURCES LTD'},
#  '540': {'cik_str': 839923,
#   'ticker': 'VOD',
#   'title': 'VODAFONE GROUP PUBLIC LTD CO'},
#  '541': {'cik_str': 105770,
#   'ticker': 'WST',
#   'title': 'WEST PHARMACEUTICAL SERVICES INC'},
#  '542': {'cik_str': 11544, 'ticker': 'WRB', 'title': 'BERKLEY W R CORP'},
#  '543': {'cik_str': 1001250,
#   'ticker': 'EL',
#   'title': 'ESTEE LAUDER COMPANIES INC'},
#  '544': {'cik_str': 1725964, 'ticker': 'NTR', 'title': 'Nutrien Ltd.'},
#  '545': {'cik_str': 1709048, 'ticker': 'GFS', 'title': 'GLOBALFOUNDRIES Inc.'},
#  '546': {'cik_str': 1400691,
#   'ticker': 'HDELY',
#   'title': 'HeidelbergCement AG'},
#  '547': {'cik_str': 857005, 'ticker': 'PTC', 'title': 'PTC INC.'},
#  '548': {'cik_str': 868675, 'ticker': 'TU', 'title': 'TELUS CORP'},
#  '549': {'cik_str': 932787,
#   'ticker': 'STM',
#   'title': 'STMicroelectronics N.V.'},
#  '550': {'cik_str': 72741, 'ticker': 'ES', 'title': 'EVERSOURCE ENERGY'},
#  '551': {'cik_str': 1437107,
#   'ticker': 'WBD',
#   'title': 'Warner Bros. Discovery, Inc.'},
#  '552': {'cik_str': 731802, 'ticker': 'ATO', 'title': 'ATMOS ENERGY CORP'},
#  '553': {'cik_str': 106535, 'ticker': 'WY', 'title': 'WEYERHAEUSER CO'},
#  '554': {'cik_str': 1136869,
#   'ticker': 'ZBH',
#   'title': 'ZIMMER BIOMET HOLDINGS, INC.'},
#  '555': {'cik_str': 51253,
#   'ticker': 'IFF',
#   'title': 'INTERNATIONAL FLAVORS & FRAGRANCES INC'},
#  '556': {'cik_str': 1456346, 'ticker': 'FNV', 'title': 'FRANCO NEVADA Corp'},
#  '557': {'cik_str': 1666175, 'ticker': 'FTS', 'title': 'Fortis Inc.'},
#  '558': {'cik_str': 895126, 'ticker': 'EXE', 'title': 'EXPAND ENERGY Corp'},
#  '559': {'cik_str': 1094285,
#   'ticker': 'TDY',
#   'title': 'TELEDYNE TECHNOLOGIES INC'},
#  '560': {'cik_str': 1096343, 'ticker': 'MKL', 'title': 'MARKEL GROUP INC.'},
#  '561': {'cik_str': 1713445, 'ticker': 'RDDT', 'title': 'Reddit, Inc.'},
#  '562': {'cik_str': 1757898, 'ticker': 'STE', 'title': 'STERIS plc'},
#  '563': {'cik_str': 1069202,
#   'ticker': 'LII',
#   'title': 'LENNOX INTERNATIONAL INC'},
#  '564': {'cik_str': 1985487,
#   'ticker': 'KSPI',
#   'title': 'Joint Stock Co Kaspi.kz'},
#  '565': {'cik_str': 1336920,
#   'ticker': 'LDOS',
#   'title': 'Leidos Holdings, Inc.'},
#  '566': {'cik_str': 106040, 'ticker': 'WDC', 'title': 'WESTERN DIGITAL CORP'},
#  '567': {'cik_str': 1110803, 'ticker': 'ILMN', 'title': 'ILLUMINA, INC.'},
#  '568': {'cik_str': 1116578, 'ticker': 'PUK', 'title': 'PRUDENTIAL PLC'},
#  '569': {'cik_str': 1000697, 'ticker': 'WAT', 'title': 'WATERS CORP /DE/'},
#  '570': {'cik_str': 1669414,
#   'ticker': 'SMPNY',
#   'title': 'Sompo Japan Nipponkoa Holdings, Inc./ADR'},
#  '571': {'cik_str': 73124, 'ticker': 'NTRS', 'title': 'NORTHERN TRUST CORP'},
#  '572': {'cik_str': 1093028,
#   'ticker': 'EJPRY',
#   'title': 'EAST JAPAN RAILWAY CO /FI'},
#  '573': {'cik_str': 1022671, 'ticker': 'STLD', 'title': 'STEEL DYNAMICS INC'},
#  '574': {'cik_str': 75677,
#   'ticker': 'PKG',
#   'title': 'PACKAGING CORP OF AMERICA'},
#  '575': {'cik_str': 922621, 'ticker': 'ERIE', 'title': 'ERIE INDEMNITY CO'},
#  '576': {'cik_str': 1374310,
#   'ticker': 'CBOE',
#   'title': 'Cboe Global Markets, Inc.'},
#  '577': {'cik_str': 1651308, 'ticker': 'BGNE', 'title': 'BeiGene, Ltd.'},
#  '578': {'cik_str': 105016, 'ticker': 'WSO', 'title': 'WATSCO INC'},
#  '579': {'cik_str': 21076, 'ticker': 'CLX', 'title': 'CLOROX CO /DE/'},
#  '580': {'cik_str': 1122411,
#   'ticker': 'ASX',
#   'title': 'ASE Technology Holding Co., Ltd.'},
#  '581': {'cik_str': 1158967, 'ticker': 'NJDCY', 'title': 'NIDEC CORP'},
#  '582': {'cik_str': 1417663,
#   'ticker': 'SNWV',
#   'title': 'SANUWAVE Health, Inc.'},
#  '583': {'cik_str': 1687229,
#   'ticker': 'INVH',
#   'title': 'Invitation Homes Inc.'},
#  '584': {'cik_str': 1274494, 'ticker': 'FSLR', 'title': 'FIRST SOLAR, INC.'},
#  '585': {'cik_str': 1190723, 'ticker': 'TS', 'title': 'TENARIS SA'},
#  '586': {'cik_str': 1511737, 'ticker': 'UI', 'title': 'Ubiquiti Inc.'},
#  '587': {'cik_str': 759944,
#   'ticker': 'CFG',
#   'title': 'CITIZENS FINANCIAL GROUP INC/RI'},
#  '588': {'cik_str': 1137789,
#   'ticker': 'STX',
#   'title': 'Seagate Technology Holdings plc'},
#  '589': {'cik_str': 811156, 'ticker': 'CMS', 'title': 'CMS ENERGY CORP'},
#  '590': {'cik_str': 1441816, 'ticker': 'MDB', 'title': 'MongoDB, Inc.'},
#  '591': {'cik_str': 1316835,
#   'ticker': 'BLDR',
#   'title': 'Builders FirstSource, Inc.'},
#  '592': {'cik_str': 790051,
#   'ticker': 'CSL',
#   'title': 'CARLISLE COMPANIES INC'},
#  '593': {'cik_str': 1754301, 'ticker': 'FOXA', 'title': 'Fox Corp'},
#  '594': {'cik_str': 1334687,
#   'ticker': 'CJPRY',
#   'title': 'CENTRAL JAPAN RAILWAY CO'},
#  '595': {'cik_str': 920522,
#   'ticker': 'ESS',
#   'title': 'ESSEX PROPERTY TRUST, INC.'},
#  '596': {'cik_str': 63754, 'ticker': 'MKC', 'title': 'MCCORMICK & CO INC'},
#  '597': {'cik_str': 764478, 'ticker': 'BBY', 'title': 'BEST BUY CO INC'},
#  '598': {'cik_str': 877212,
#   'ticker': 'ZBRA',
#   'title': 'ZEBRA TECHNOLOGIES CORP'},
#  '599': {'cik_str': 711404,
#   'ticker': 'COO',
#   'title': 'COOPER COMPANIES, INC.'},
#  '600': {'cik_str': 1130310,
#   'ticker': 'CNP',
#   'title': 'CENTERPOINT ENERGY INC'},
# ...
#  '806': {'cik_str': 1294591,
#   'ticker': 'RKUNY',
#   'title': 'Rakuten Group, Inc.'},
#  '807': {'cik_str': 1037976,
#   'ticker': 'JLL',
#   'title': 'JONES LANG LASALLE INC'},
#  '808': {'cik_str': 1810997, 'ticker': 'XPEV', 'title': 'XPENG INC.'},
#  '809': {'cik_str': 216228, 'ticker': 'ITT', 'title': 'ITT INC.'},
#  '810': {'cik_str': 1910139,
#   'ticker': 'MBLY',
#   'title': 'Mobileye Global Inc.'},
#  '811': {'cik_str': 1070750,
#   'ticker': 'HST',
#   'title': 'HOST HOTELS & RESORTS, INC.'},
#  '812': {'cik_str': 802481, 'ticker': 'PPC', 'title': 'PILGRIMS PRIDE CORP'},
#  '813': {'cik_str': 1172724, 'ticker': 'GFI', 'title': 'GOLD FIELDS LTD'},
#  '814': {'cik_str': 1043604,
#   'ticker': 'JNPR',
#   'title': 'JUNIPER NETWORKS INC'},
#  '815': {'cik_str': 1517231,
#   'ticker': 'SSMXY',
#   'title': 'Sysmex Corporation/ADR'},
#  '816': {'cik_str': 1025378, 'ticker': 'WPC', 'title': 'W. P. Carey Inc.'},
#  '817': {'cik_str': 1754581, 'ticker': 'FUTU', 'title': 'Futu Holdings Ltd'},
#  '818': {'cik_str': 1588823,
#   'ticker': 'TFII',
#   'title': 'TFI International Inc.'},
#  '819': {'cik_str': 1579241, 'ticker': 'ALLE', 'title': 'Allegion plc'},
#  '820': {'cik_str': 1070423,
#   'ticker': 'PAA',
#   'title': 'PLAINS ALL AMERICAN PIPELINE LP'},
#  '821': {'cik_str': 1504122,
#   'ticker': 'PTBRY',
#   'title': 'PT Bank Negara Indonesia (Persero) Tbk/ADR'},
#  '822': {'cik_str': 1048477,
#   'ticker': 'BMRN',
#   'title': 'BIOMARIN PHARMACEUTICAL INC'},
#  '823': {'cik_str': 1326380, 'ticker': 'GME', 'title': 'GameStop Corp.'},
#  '824': {'cik_str': 89089,
#   'ticker': 'SCI',
#   'title': 'SERVICE CORP INTERNATIONAL'},
#  '825': {'cik_str': 1170010, 'ticker': 'KMX', 'title': 'CARMAX INC'},
#  '826': {'cik_str': 915913, 'ticker': 'ALB', 'title': 'ALBEMARLE CORP'},
#  '827': {'cik_str': 1135951,
#   'ticker': 'RDY',
#   'title': 'DR REDDYS LABORATORIES LTD'},
#  '828': {'cik_str': 1600520,
#   'ticker': 'JPXGY',
#   'title': 'Japan Exchange Group, Inc./ADR'},
#  '829': {'cik_str': 1720635, 'ticker': 'NVT', 'title': 'nVent Electric plc'},
#  '830': {'cik_str': 914475,
#   'ticker': 'NBIX',
#   'title': 'NEUROCRINE BIOSCIENCES INC'},
#  '831': {'cik_str': 1681459, 'ticker': 'FTI', 'title': 'TechnipFMC plc'},
#  '832': {'cik_str': 1658566,
#   'ticker': 'PR',
#   'title': 'Permian Resources Corp'},
#  '833': {'cik_str': 1032975,
#   'ticker': 'LOGI',
#   'title': 'LOGITECH INTERNATIONAL S.A.'},
#  '834': {'cik_str': 1104506, 'ticker': 'INSM', 'title': 'INSMED Inc'},
#  '835': {'cik_str': 1725057, 'ticker': 'DAY', 'title': 'Dayforce, Inc.'},
#  '836': {'cik_str': 915389, 'ticker': 'EMN', 'title': 'EASTMAN CHEMICAL CO'},
#  '837': {'cik_str': 1281721, 'ticker': 'SGIOY', 'title': 'SHIONOGI & CO LTD'},
#  '838': {'cik_str': 720672, 'ticker': 'SF', 'title': 'STIFEL FINANCIAL CORP'},
#  '839': {'cik_str': 1531152,
#   'ticker': 'BJ',
#   'title': "BJ's Wholesale Club Holdings, Inc."},
#  '840': {'cik_str': 1964738, 'ticker': 'SOLV', 'title': 'Solventum Corp'},
#  '841': {'cik_str': 59527,
#   'ticker': 'LECO',
#   'title': 'LINCOLN ELECTRIC HOLDINGS INC'},
#  '842': {'cik_str': 4457, 'ticker': 'UHAL', 'title': 'U-Haul Holding Co /NV/'},
#  '843': {'cik_str': 1161125, 'ticker': 'BCH', 'title': 'BANK OF CHILE'},
#  '844': {'cik_str': 1513761,
#   'ticker': 'NCLH',
#   'title': 'Norwegian Cruise Line Holdings Ltd.'},
#  '845': {'cik_str': 1042046,
#   'ticker': 'AFG',
#   'title': 'AMERICAN FINANCIAL GROUP INC'},
#  '846': {'cik_str': 1170858,
#   'ticker': 'SBS',
#   'title': 'COMPANHIA DE SANEAMENTO BASICO DO ESTADO DE SAO PAULO-SABESP'},
#  '847': {'cik_str': 1486957,
#   'ticker': 'BWXT',
#   'title': 'BWX Technologies, Inc.'},
#  '848': {'cik_str': 1446444,
#   'ticker': 'TKHVY',
#   'title': 'Turk Hava Yollari A.O.'},
#  '849': {'cik_str': 1675149, 'ticker': 'AA', 'title': 'Alcoa Corp'},
#  '850': {'cik_str': 1450346,
#   'ticker': 'POAHY',
#   'title': 'Porsche Automobil Holding SE / ADR'},
#  '851': {'cik_str': 353991,
#   'ticker': 'NDEKY',
#   'title': 'NITTO DENKO CORP / ADR/'},
#  '852': {'cik_str': 91419, 'ticker': 'SJM', 'title': 'J M SMUCKER Co'},
#  '853': {'cik_str': 701818, 'ticker': 'KGC', 'title': 'KINROSS GOLD CORP'},
#  '854': {'cik_str': 1360901, 'ticker': 'EVR', 'title': 'Evercore Inc.'},
#  '855': {'cik_str': 1792580, 'ticker': 'OVV', 'title': 'Ovintiv Inc.'},
#  '856': {'cik_str': 38777, 'ticker': 'BEN', 'title': 'FRANKLIN RESOURCES INC'},
#  '857': {'cik_str': 896622, 'ticker': 'ATR', 'title': 'APTARGROUP, INC.'},
#  '858': {'cik_str': 82811, 'ticker': 'RRX', 'title': 'REGAL REXNORD CORP'},
#  '859': {'cik_str': 1483994, 'ticker': 'HTHT', 'title': 'H World Group Ltd'},
#  '860': {'cik_str': 1267238, 'ticker': 'AIZ', 'title': 'ASSURANT, INC.'},
#  '861': {'cik_str': 888491,
#   'ticker': 'OHI',
#   'title': 'OMEGA HEALTHCARE INVESTORS INC'},
#  '862': {'cik_str': 789570,
#   'ticker': 'MGM',
#   'title': 'MGM Resorts International'},
#  '863': {'cik_str': 1591698,
#   'ticker': 'PCTY',
#   'title': 'Paylocity Holding Corp'},
#  '864': {'cik_str': 806968, 'ticker': 'WPP', 'title': 'WPP plc'},
#  '865': {'cik_str': 40729, 'ticker': 'ALLY', 'title': 'Ally Financial Inc.'},
#  '866': {'cik_str': 1237831, 'ticker': 'GMED', 'title': 'GLOBUS MEDICAL INC'},
#  '867': {'cik_str': 1043219,
#   'ticker': 'NLY',
#   'title': 'ANNALY CAPITAL MANAGEMENT INC'},
#  '868': {'cik_str': 1646972,
#   'ticker': 'ACI',
#   'title': 'Albertsons Companies, Inc.'},
#  '869': {'cik_str': 1298675, 'ticker': 'CUBE', 'title': 'CubeSmart'},
#  '870': {'cik_str': 1507079,
#   'ticker': 'FND',
#   'title': 'Floor & Decor Holdings, Inc.'},
#  '871': {'cik_str': 831641, 'ticker': 'TTEK', 'title': 'TETRA TECH INC'},
#  '872': {'cik_str': 1679273,
#   'ticker': 'LW',
#   'title': 'Lamb Weston Holdings, Inc.'},
#  '873': {'cik_str': 1468608,
#   'ticker': 'VDMCY',
#   'title': 'Vodacom Group Ltd / ADR'},
#  '874': {'cik_str': 1495153, 'ticker': 'MMYT', 'title': 'MakeMyTrip Ltd'},
#  '875': {'cik_str': 1062066, 'ticker': 'ALSMY', 'title': 'ALSTOM'},
#  '876': {'cik_str': 1446656, 'ticker': 'KIKOY', 'title': 'Kikkoman Corp'},
#  '877': {'cik_str': 1003935, 'ticker': 'NICE', 'title': 'NICE Ltd.'},
#  '878': {'cik_str': 1669162,
#   'ticker': 'KNSL',
#   'title': 'Kinsale Capital Group, Inc.'},
#  '879': {'cik_str': 845982, 'ticker': 'SNN', 'title': 'SMITH & NEPHEW PLC'},
#  '880': {'cik_str': 842023, 'ticker': 'TECH', 'title': 'BIO-TECHNE Corp'},
#  '881': {'cik_str': 1596783, 'ticker': 'CTLT', 'title': 'Catalent, Inc.'},
#  '882': {'cik_str': 1649094, 'ticker': 'PCVX', 'title': 'Vaxcyte, Inc.'},
#  '883': {'cik_str': 1019849,
#   'ticker': 'PAG',
#   'title': 'PENSKE AUTOMOTIVE GROUP, INC.'},
#  '884': {'cik_str': 1219601, 'ticker': 'CCK', 'title': 'CROWN HOLDINGS, INC.'},
#  '885': {'cik_str': 1474735,
#   'ticker': 'GNRC',
#   'title': 'GENERAC HOLDINGS INC.'},
#  '886': {'cik_str': 36966, 'ticker': 'FHN', 'title': 'FIRST HORIZON CORP'},
#  '887': {'cik_str': 1573516, 'ticker': 'MUSA', 'title': 'Murphy USA Inc.'},
#  '888': {'cik_str': 15615, 'ticker': 'MTZ', 'title': 'MASTEC INC'},
#  '889': {'cik_str': 1579091, 'ticker': 'CART', 'title': 'Maplebear Inc.'},
#  '890': {'cik_str': 824142, 'ticker': 'AAON', 'title': 'AAON, INC.'},
#  '891': {'cik_str': 909037,
#   'ticker': 'SQM',
#   'title': 'CHEMICAL & MINING CO OF CHILE INC'},
#  '892': {'cik_str': 1433642, 'ticker': 'HLNE', 'title': 'Hamilton Lane INC'},
#  '893': {'cik_str': 1555812,
#   'ticker': 'SMKUY',
#   'title': 'Siam Makro Public Co Limited/ADR'},
#  '894': {'cik_str': 78128,
#   'ticker': 'WTRG',
#   'title': 'Essential Utilities, Inc.'},
#  '895': {'cik_str': 769218, 'ticker': 'AEG', 'title': 'AEGON LTD.'},
#  '896': {'cik_str': 1127248, 'ticker': 'EMRAF', 'title': 'EMERA INC'},
#  '897': {'cik_str': 1027664, 'ticker': 'ESLT', 'title': 'ELBIT SYSTEMS LTD'},
#  '898': {'cik_str': 91142, 'ticker': 'AOS', 'title': 'SMITH A O CORP'},
#  '899': {'cik_str': 317540,
#   'ticker': 'COKE',
#   'title': 'Coca-Cola Consolidated, Inc.'},
#  '900': {'cik_str': 1545772,
#   'ticker': 'BPYPP',
#   'title': 'Brookfield Property Partners L.P.'},
#  '901': {'cik_str': 871464,
#   'ticker': 'HNGKY',
#   'title': 'HONGKONG LAND HOLDINGS LTD /FI'},
#  '902': {'cik_str': 887225,
#   'ticker': 'KEP',
#   'title': 'KOREA ELECTRIC POWER CORP'},
#  '903': {'cik_str': 16058,
#   'ticker': 'CACI',
#   'title': 'CACI INTERNATIONAL INC /DE/'},
#  '904': {'cik_str': 764622,
#   'ticker': 'PNW',
#   'title': 'PINNACLE WEST CAPITAL CORP'},
#  '905': {'cik_str': 1375365,
#   'ticker': 'SMCI',
#   'title': 'Super Micro Computer, Inc.'},
#  '906': {'cik_str': 350894, 'ticker': 'SEIC', 'title': 'SEI INVESTMENTS CO'},
#  '907': {'cik_str': 1611052,
#   'ticker': 'PCOR',
#   'title': 'PROCORE TECHNOLOGIES, INC.'},
#  '908': {'cik_str': 109563,
#   'ticker': 'AIT',
#   'title': 'APPLIED INDUSTRIAL TECHNOLOGIES INC'},
#  '909': {'cik_str': 275880, 'ticker': 'PSN', 'title': 'PARSONS CORP'},
#  '910': {'cik_str': 1633931, 'ticker': 'BLD', 'title': 'TopBuild Corp'},
#  '911': {'cik_str': 20212, 'ticker': 'CHDN', 'title': 'Churchill Downs Inc'},
#  '912': {'cik_str': 1622536, 'ticker': 'TLN', 'title': 'Talen Energy Corp'},
#  '913': {'cik_str': 108312, 'ticker': 'WWD', 'title': 'Woodward, Inc.'},
#  '914': {'cik_str': 801337,
#   'ticker': 'WBS',
#   'title': 'WEBSTER FINANCIAL CORP'},
#  '915': {'cik_str': 51644,
#   'ticker': 'IPG',
#   'title': 'INTERPUBLIC GROUP OF COMPANIES, INC.'},
#  '916': {'cik_str': 1078642, 'ticker': 'CRRFY', 'title': 'CARREFOUR SA'},
#  '917': {'cik_str': 1604028,
#   'ticker': 'WMS',
#   'title': 'ADVANCED DRAINAGE SYSTEMS, INC.'},
#  '918': {'cik_str': 1144215, 'ticker': 'AYI', 'title': 'ACUITY BRANDS INC'},
#  '919': {'cik_str': 89439, 'ticker': 'MLI', 'title': 'MUELLER INDUSTRIES INC'},
#  '920': {'cik_str': 1428439, 'ticker': 'ROKU', 'title': 'ROKU, INC'},
#  '921': {'cik_str': 918646, 'ticker': 'EXP', 'title': 'EAGLE MATERIALS INC'},
#  '922': {'cik_str': 785161, 'ticker': 'EHC', 'title': 'Encompass Health Corp'},
#  '923': {'cik_str': 1874178,
#   'ticker': 'RIVN',
#   'title': 'Rivian Automotive, Inc. / DE'},
#  '924': {'cik_str': 1411207,
#   'ticker': 'ALSN',
#   'title': 'Allison Transmission Holdings Inc'},
#  '925': {'cik_str': 1783398, 'ticker': 'UWMC', 'title': 'UWM Holdings Corp'},
#  '926': {'cik_str': 1973832, 'ticker': 'AU', 'title': 'AngloGold Ashanti PLC'},
#  '927': {'cik_str': 938323, 'ticker': 'PSO', 'title': 'PEARSON PLC'},
#  '928': {'cik_str': 1541309,
#   'ticker': 'CSXXY',
#   'title': 'carsales.com Limited/ADR'},
#  '929': {'cik_str': 1065696, 'ticker': 'LKQ', 'title': 'LKQ CORP'},
#  '930': {'cik_str': 929008,
#   'ticker': 'WCC',
#   'title': 'WESCO INTERNATIONAL INC'},
#  '931': {'cik_str': 1901440, 'ticker': 'ULS', 'title': 'UL Solutions Inc.'},
#  '932': {'cik_str': 1023128, 'ticker': 'LAD', 'title': 'LITHIA MOTORS INC'},
#  '933': {'cik_str': 1944013, 'ticker': 'CR', 'title': 'Crane Co'},
#  '934': {'cik_str': 939767, 'ticker': 'EXEL', 'title': 'EXELIXIS, INC.'},
#  '935': {'cik_str': 1584509, 'ticker': 'ARMK', 'title': 'Aramark'},
#  '936': {'cik_str': 1475922, 'ticker': 'PRI', 'title': 'Primerica, Inc.'},
#  '937': {'cik_str': 1174922, 'ticker': 'WYNN', 'title': 'WYNN RESORTS LTD'},
#  '938': {'cik_str': 1212545,
#   'ticker': 'WAL',
#   'title': 'WESTERN ALLIANCE BANCORPORATION'},
#  '939': {'cik_str': 873303,
#   'ticker': 'SRPT',
#   'title': 'Sarepta Therapeutics, Inc.'},
#  '940': {'cik_str': 1576789, 'ticker': 'WIX', 'title': 'Wix.com Ltd.'},
#  '941': {'cik_str': 1278021,
#   'ticker': 'MKTX',
#   'title': 'MARKETAXESS HOLDINGS INC'},
#  '942': {'cik_str': 874761, 'ticker': 'AES', 'title': 'AES CORP'},
#  '943': {'cik_str': 1447126,
#   'ticker': 'KAIKY',
#   'title': 'Kawasaki Kisen Kaisha Ltd'},
#  '944': {'cik_str': 1668397,
#   'ticker': 'MEDP',
#   'title': 'Medpace Holdings, Inc.'},
#  '945': {'cik_str': 1324948, 'ticker': 'RBC', 'title': 'RBC Bearings INC'},
#  '946': {'cik_str': 1988894, 'ticker': 'AS', 'title': 'Amer Sports, Inc.'},
#  '947': {'cik_str': 1177394, 'ticker': 'SNX', 'title': 'TD SYNNEX CORP'},
#  '948': {'cik_str': 1842022, 'ticker': 'DTM', 'title': 'DT Midstream, Inc.'},
#  '949': {'cik_str': 1796209, 'ticker': 'APG', 'title': 'APi Group Corp'},
#  '950': {'cik_str': 34903,
#   'ticker': 'FRT',
#   'title': 'FEDERAL REALTY INVESTMENT TRUST'},
#  '951': {'cik_str': 936395, 'ticker': 'CIEN', 'title': 'CIENA CORP'},
#  '952': {'cik_str': 1062579, 'ticker': 'DOX', 'title': 'AMDOCS LTD'},
#  '953': {'cik_str': 1571283,
#   'ticker': 'REXR',
#   'title': 'Rexford Industrial Realty, Inc.'},
#  '954': {'cik_str': 1100682,
#   'ticker': 'CRL',
#   'title': 'CHARLES RIVER LABORATORIES INTERNATIONAL, INC.'},
#  '955': {'cik_str': 1973266,
#   'ticker': 'TKO',
#   'title': 'TKO Group Holdings, Inc.'},
#  '956': {'cik_str': 1602065, 'ticker': 'VNOM', 'title': 'Viper Energy, Inc.'},
#  '957': {'cik_str': 1835830, 'ticker': 'KVYO', 'title': 'Klaviyo, Inc.'},
#  '958': {'cik_str': 1050140,
#   'ticker': 'DSGX',
#   'title': 'DESCARTES SYSTEMS GROUP INC'},
#  '959': {'cik_str': 1115055,
#   'ticker': 'PNFP',
#   'title': 'PINNACLE FINANCIAL PARTNERS INC'},
#  '960': {'cik_str': 1653482, 'ticker': 'GTLB', 'title': 'Gitlab Inc.'},
#  '961': {'cik_str': 1030894, 'ticker': 'CLS', 'title': 'CELESTICA INC'},
#  '962': {'cik_str': 1736541, 'ticker': 'NIO', 'title': 'NIO Inc.'},
#  '963': {'cik_str': 74260,
#   'ticker': 'ORI',
#   'title': 'OLD REPUBLIC INTERNATIONAL CORP'},
#  '964': {'cik_str': 1206264,
#   'ticker': 'TPX',
#   'title': 'TEMPUR SEALY INTERNATIONAL, INC.'},
#  '965': {'cik_str': 1131383, 'ticker': 'STN', 'title': 'STANTEC INC'},
#  '966': {'cik_str': 1433270, 'ticker': 'AR', 'title': 'ANTERO RESOURCES Corp'},
#  '967': {'cik_str': 1330568, 'ticker': 'SLV', 'title': 'iShares Silver Trust'},
#  '968': {'cik_str': 1438654,
#   'ticker': 'RDEIY',
#   'title': 'Red Electrica Corporacion SA/ADR'},
#  '969': {'cik_str': 1481045,
#   'ticker': 'DSEEY',
#   'title': 'Daiwa Securities Group Inc.'},
#  '970': {'cik_str': 1819994,
#   'ticker': 'RKLB',
#   'title': 'Rocket Lab USA, Inc.'},
#  '971': {'cik_str': 6201,
#   'ticker': 'AAL',
#   'title': 'American Airlines Group Inc.'},
#  '972': {'cik_str': 1772016,
#   'ticker': 'BRBR',
#   'title': 'BELLRING BRANDS, INC.'},
#  '973': {'cik_str': 1440130,
#   'ticker': 'UUGRY',
#   'title': 'United Utilities Group plc'},
#  '974': {'cik_str': 2025410, 'ticker': 'SARO', 'title': 'StandardAero, Inc.'},
#  '975': {'cik_str': 1628171,
#   'ticker': 'RVMD',
#   'title': 'Revolution Medicines, Inc.'},
#  '976': {'cik_str': 1636222, 'ticker': 'WING', 'title': 'Wingstop Inc.'},
#  '977': {'cik_str': 85535, 'ticker': 'RGLD', 'title': 'ROYAL GOLD INC'},
#  '978': {'cik_str': 1519751,
#   'ticker': 'FBIN',
#   'title': 'Fortune Brands Innovations, Inc.'},
#  '979': {'cik_str': 1516513, 'ticker': 'DOCS', 'title': 'Doximity, Inc.'},
#  '980': {'cik_str': 1046257, 'ticker': 'INGR', 'title': 'Ingredion Inc'},
#  '981': {'cik_str': 1124140, 'ticker': 'EXAS', 'title': 'EXACT SCIENCES CORP'},
#  '982': {'cik_str': 29644, 'ticker': 'DCI', 'title': 'DONALDSON Co INC'},
#  '983': {'cik_str': 22356,
#   'ticker': 'CBSH',
#   'title': 'COMMERCE BANCSHARES INC /MO/'},
#  '984': {'cik_str': 1065837, 'ticker': 'SKX', 'title': 'SKECHERS USA INC'},
#  '985': {'cik_str': 1321732, 'ticker': 'PEN', 'title': 'Penumbra Inc'},
#  '986': {'cik_str': 320335, 'ticker': 'GL', 'title': 'GLOBE LIFE INC.'},
#  '987': {'cik_str': 1015820, 'ticker': 'QGEN', 'title': 'QIAGEN N.V.'},
#  '988': {'cik_str': 1372920,
#   'ticker': 'EDU',
#   'title': 'New Oriental Education & Technology Group Inc.'},
#  '989': {'cik_str': 28412, 'ticker': 'CMA', 'title': 'COMERICA INC /NEW/'},
#  '990': {'cik_str': 1027552,
#   'ticker': 'BSAC',
#   'title': 'BANCO SANTANDER CHILE'},
#  '991': {'cik_str': 1913510, 'ticker': 'VFS', 'title': 'VinFast Auto Ltd.'},
#  '992': {'cik_str': 12208,
#   'ticker': 'BIO',
#   'title': 'BIO-RAD LABORATORIES, INC.'},
#  '993': {'cik_str': 1492691,
#   'ticker': 'KNX',
#   'title': 'Knight-Swift Transportation Holdings Inc.'},
#  '994': {'cik_str': 1124198, 'ticker': 'FLR', 'title': 'FLUOR CORP'},
#  '995': {'cik_str': 1380365,
#   'ticker': 'IDKOY',
#   'title': 'IDEMITSU KOSAN CO., LTD'},
#  '996': {'cik_str': 1766363,
#   'ticker': 'EDR',
#   'title': 'Endeavor Group Holdings, Inc.'},
#  '997': {'cik_str': 1833756, 'ticker': 'DRS', 'title': 'Leonardo DRS, Inc.'},
#  '998': {'cik_str': 1493594,
#   'ticker': 'MTSI',
#   'title': 'MACOM Technology Solutions Holdings, Inc.'},
#  '999': {'cik_str': 1567514,
#   'ticker': 'ITCI',
#   'title': 'Intra-Cellular Therapies, Inc.'},
#  ...}

# %%
len(company_tickers)
# Out:
# 9998

# %% [markdown]
# # Inserting Stocks into Pinecone
#
# **1. Create an account on [Pinecone.io](https://app.pinecone.io/)**
#
# **2. Create a new index called "stocks" and set the dimensions to 768. Leave the rest of the settings as they are.**
#
# ![Screenshot 2024-12-02 at 4 48 03 PM](https://github.com/user-attachments/assets/13b484da-cd00-4337-a4db-4779080eb42c)
#
#
# **3. Create an API Key for Pinecone**
#
# ![Screenshot 2024-11-24 at 10 44 37 PM](https://github.com/user-attachments/assets/e7feacc6-2bd1-472a-82e5-659f65624a88)
#
#
# **4. Store your Pinecone API Key within Google Colab's secrets section, and then enable access to it (see the blue checkmark)**
#
#
# ![Screenshot 2024-11-24 at 10 45 25 PM](https://github.com/user-attachments/assets/eaf73083-0b5f-4d17-9e0c-eab84f91b0bc)

# %%
pinecone_api_key = userdata.get("PINECONE_API_KEY")
os.environ['PINECONE_API_KEY'] = pinecone_api_key

index_name = "stocks"
namespace = "stock-descriptions"

hf_embeddings = HuggingFaceEmbeddings()
vectorstore = PineconeVectorStore(index_name=index_name, embedding=hf_embeddings)
# Out:
# <ipython-input-41-8d5c0f356cf6>:7: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   hf_embeddings = HuggingFaceEmbeddings()

# %% [markdown]
# # Sequential Processing
#
# It will take very long to process all the stocks like this!

# %% [markdown]
# [![](https://mermaid.ink/img/pako:eNqNkl1rgzAUhv9KyMXYwF74cSVjYA0rhY6WKRQWe5FqWqU1cUm8GKX_ffmwa65Gc6Hn5LxvzmM8F1jzhsIUHgUZWlCiigG9MlwoXp_AqpPqdS_esmyzCsBivV7o10fxXgagLFbZDsxmb2COi44dzxRsBK-plDoBZSsoaXbuNPeU4941qWBBv0fKVEfOvud5yejh0NWdLr1U0LnMmts2eYhDMLsZgEHa3TV5aEXbEG-zZZnasiXfLMGnaScVeNKRHDiT1DNunRGF5pMFtUaAiCKe5h4hp84jHHks9mJ8mMjBRBOMrT9G45wommis84bjYThZHuPYwzA_xqeIHUU8UZjyYxDOiOIJwhj_uRKnzhOc3FHsdHgoiUNJJhRTfgzFGVEyoRijj0JZAwPYU9GTrtFjfDHbFVQt7WkFUx02RJzMMF21joyKFz-shqkSIw2g4OOxhemBnKXOxqEhiqKO6DHt_3YHwr44v-XXX7It6B4?type=png)](https://mermaid.live/edit#pako:eNqNkl1rgzAUhv9KyMXYwF74cSVjYA0rhY6WKRQWe5FqWqU1cUm8GKX_ffmwa65Gc6Hn5LxvzmM8F1jzhsIUHgUZWlCiigG9MlwoXp_AqpPqdS_esmyzCsBivV7o10fxXgagLFbZDsxmb2COi44dzxRsBK-plDoBZSsoaXbuNPeU4941qWBBv0fKVEfOvud5yejh0NWdLr1U0LnMmts2eYhDMLsZgEHa3TV5aEXbEG-zZZnasiXfLMGnaScVeNKRHDiT1DNunRGF5pMFtUaAiCKe5h4hp84jHHks9mJ8mMjBRBOMrT9G45wommis84bjYThZHuPYwzA_xqeIHUU8UZjyYxDOiOIJwhj_uRKnzhOc3FHsdHgoiUNJJhRTfgzFGVEyoRijj0JZAwPYU9GTrtFjfDHbFVQt7WkFUx02RJzMMF21joyKFz-shqkSIw2g4OOxhemBnKXOxqEhiqKO6DHt_3YHwr44v-XXX7It6B4)

# %%
for idx, stock in company_tickers.items():
    stock_ticker = stock['ticker']
    stock_data = get_stock_info(stock_ticker)
    stock_description = stock_data['Business Summary']

    print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)

    vectorstore_from_documents = PineconeVectorStore.from_documents(
        documents=[Document(page_content=stock_description, metadata=stock_data)],
        embedding=hf_embeddings,
        index_name=index_name,
        namespace=namespace
    )
# Out:
# Processing stock 0 / 9998 : NVDA
# Processing stock 1 / 9998 : AAPL
# Processing stock 2 / 9998 : MSFT
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-0b4e6262b270> in <cell line: 1>()
#       6     print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)
#       7
# ----> 8     vectorstore_from_documents = PineconeVectorStore.from_documents(
#       9         documents=[Document(page_content=stock_description, metadata=stock_data)],
#      10         embedding=hf_embeddings,
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/vectorstores/base.py in from_documents(cls, documents, embedding, **kwargs)
#     850                 kwargs["ids"] = ids
#     851
# --> 852         return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#     853
#     854     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in from_texts(cls, texts, embedding, metadatas, ids, batch_size, text_key, namespace, index_name, upsert_kwargs, pool_threads, embeddings_chunk_size, async_req, id_prefix, **kwargs)
#     581         pinecone = cls(pinecone_index, embedding, text_key, namespace, **kwargs)
#     582
# --> 583         pinecone.add_texts(
#     584             texts,
#     585             metadatas=metadatas,
#
# /usr/local/lib/python3.10/dist-packages/langchain_pinecone/vectorstores.py in add_texts(self, texts, metadatas, ids, namespace, batch_size, embedding_chunk_size, async_req, id_prefix, **kwargs)
#     277             chunk_ids = ids[i : i + embedding_chunk_size]
#     278             chunk_metadatas = metadatas[i : i + embedding_chunk_size]
# --> 279             embeddings = self._embedding.embed_documents(chunk_texts)
#     280             vector_tuples = zip(chunk_ids, embeddings, chunk_metadatas)
#     281             if async_req:
#
# /usr/local/lib/python3.10/dist-packages/langchain_community/embeddings/huggingface.py in embed_documents(self, texts)
#     113             sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     114         else:
# --> 115             embeddings = self.client.encode(
#     116                 texts, show_progress_bar=self.show_progress, **self.encode_kwargs
#     117             )
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings, **kwargs)
#     619
#     620             with torch.no_grad():
# --> 621                 out_features = self.forward(features, **kwargs)
#     622                 if self.device.type == "hpu":
#     623                     out_features = copy.deepcopy(out_features)
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/SentenceTransformer.py in forward(self, input, **kwargs)
#     686             module_kwarg_keys = self.module_kwargs.get(module_name, [])
#     687             module_kwargs = {key: value for key, value in kwargs.items() if key in module_kwarg_keys}
# --> 688             input = module(input, **module_kwargs)
#     689         return input
#     690
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/sentence_transformers/models/Transformer.py in forward(self, features, **kwargs)
#     348             trans_features["token_type_ids"] = features["token_type_ids"]
#     349
# --> 350         output_states = self.auto_model(**trans_features, **kwargs, return_dict=False)
#     351         output_tokens = output_states[0]
#     352
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, input_ids, attention_mask, position_ids, head_mask, inputs_embeds, output_attentions, output_hidden_states, return_dict, **kwargs)
#     542         head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
#     543         embedding_output = self.embeddings(input_ids=input_ids, position_ids=position_ids, inputs_embeds=inputs_embeds)
# --> 544         encoder_outputs = self.encoder(
#     545             embedding_output,
#     546             attention_mask=extended_attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, output_attentions, output_hidden_states, return_dict, **kwargs)
#     332                 all_hidden_states = all_hidden_states + (hidden_states,)
#     333
# --> 334             layer_outputs = layer_module(
#     335                 hidden_states,
#     336                 attention_mask,
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states, attention_mask, head_mask, position_bias, output_attentions, **kwargs)
#     301         outputs = self_attention_outputs[1:]  # add self attentions if we output attention weights
#     302
# --> 303         intermediate_output = self.intermediate(attention_output)
#     304         layer_output = self.output(intermediate_output, attention_output)
#     305         outputs = (layer_output,) + outputs
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/transformers/models/mpnet/modeling_mpnet.py in forward(self, hidden_states)
#     255
#     256     def forward(self, hidden_states: torch.Tensor) -> torch.Tensor:
# --> 257         hidden_states = self.dense(hidden_states)
#     258         hidden_states = self.intermediate_act_fn(hidden_states)
#     259         return hidden_states
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1734             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735         else:
# -> 1736             return self._call_impl(*args, **kwargs)
#    1737
#    1738     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1745                 or _global_backward_pre_hooks or _global_backward_hooks
#    1746                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747             return forward_call(*args, **kwargs)
#    1748
#    1749         result = None
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     123
#     124     def forward(self, input: Tensor) -> Tensor:
# --> 125         return F.linear(input, self.weight, self.bias)
#     126
#     127     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %% [markdown]
# # Parallelizing
#
# [![](https://mermaid.ink/img/pako:eNqFk0uLgzAQgP_KkMOe7MHXRZaC1baXvsDCwqqHrGarVJMSE9hS-983NnWxULceRmf4Pp2MyQVlLCfIQweOTwXsw4SCuvw4Eiw7wqpsxPsXn_r-bmXAcrtdqts6WuwN2Ecr3wB__blJYTKZwixe45JCwKjgrKoI7zwXdphjlVXwwfiR8CbVH9BxdjPbqKxlJTAlTDbVuYXAjDUNZveSHWcZaRromkj_F61etIbire8Xpt2b9tDslvpCdHrRGYrddF6Ibi-6D4vsBjqcUWDe_NCMl0TAG6gfwwmEWOA7FlgasEYBWwP2KOBowBkFXA24Y4COoW61DRklLcwvQUHUHooEFrK53hHrAbkX7WdF51nRfVLUcX4fs8y6ObawMON-phvyI2CGRVakyEA14TUuc7XnL52ZIFGQmiTIU4855scEJfSqOCwFi840Q57gkhiIM3kokPeNq0Zl8pRjQcISq4NT_1VPmH4y1ufXXwdkCM8?type=png)](https://mermaid.live/edit#pako:eNqFk0uLgzAQgP_KkMOe7MHXRZaC1baXvsDCwqqHrGarVJMSE9hS-983NnWxULceRmf4Pp2MyQVlLCfIQweOTwXsw4SCuvw4Eiw7wqpsxPsXn_r-bmXAcrtdqts6WuwN2Ecr3wB__blJYTKZwixe45JCwKjgrKoI7zwXdphjlVXwwfiR8CbVH9BxdjPbqKxlJTAlTDbVuYXAjDUNZveSHWcZaRromkj_F61etIbire8Xpt2b9tDslvpCdHrRGYrddF6Ibi-6D4vsBjqcUWDe_NCMl0TAG6gfwwmEWOA7FlgasEYBWwP2KOBowBkFXA24Y4COoW61DRklLcwvQUHUHooEFrK53hHrAbkX7WdF51nRfVLUcX4fs8y6ObawMON-phvyI2CGRVakyEA14TUuc7XnL52ZIFGQmiTIU4855scEJfSqOCwFi840Q57gkhiIM3kokPeNq0Zl8pRjQcISq4NT_1VPmH4y1ufXXwdkCM8)

# %%
# Initialize tracking lists
successful_tickers = []
unsuccessful_tickers = []

# Load existing successful/unsuccessful tickers
try:
    with open('successful_tickers.txt', 'r') as f:
        successful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(successful_tickers)} successful tickers")
except FileNotFoundError:
    print("No existing successful tickers file found")

try:
    with open('unsuccessful_tickers.txt', 'r') as f:
        unsuccessful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(unsuccessful_tickers)} unsuccessful tickers")
except FileNotFoundError:
    print("No existing unsuccessful tickers file found")
# Out:
# No existing successful tickers file found
# Loaded 9998 unsuccessful tickers

# %%
def process_stock(stock_ticker: str) -> str:
    # Skip if already processed
    if stock_ticker in successful_tickers:
        return f"Already processed {stock_ticker}"

    try:
        # Get and store stock data
        stock_data = get_stock_info(stock_ticker)
        stock_description = stock_data['Business Summary']

        # Store stock description in Pinecone
        vectorstore_from_texts = PineconeVectorStore.from_documents(
            documents=[Document(page_content=stock_description, metadata=stock_data)],
            embedding=hf_embeddings,
            index_name=index_name,
            namespace=namespace
        )

        # Track success
        with open('successful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        successful_tickers.append(stock_ticker)

        return f"Processed {stock_ticker} successfully"

    except Exception as e:
        # Track failure
        with open('unsuccessful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        unsuccessful_tickers.append(stock_ticker)

        return f"ERROR processing {stock_ticker}: {e}"

def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_ticker = {
            executor.submit(process_stock, ticker): ticker
            for ticker in tickers
        }

        for future in concurrent.futures.as_completed(future_to_ticker):
            ticker = future_to_ticker[future]
            try:
                result = future.result()
                print(result)

                # Stop on error
                if result.startswith("ERROR"):
                    print(f"Stopping program due to error in {ticker}")
                    executor.shutdown(wait=False)
                    raise SystemExit(1)

            except Exception as exc:
                print(f'{ticker} generated an exception: {exc}')
                print("Stopping program due to exception")
                executor.shutdown(wait=False)
                raise SystemExit(1)

# Prepare your tickers
tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# Process them
parallel_process_stocks(tickers_to_process, max_workers=10)
# Out:
# Processed TSM successfully
# Processed GOOGL successfully
# Processed META successfully
# Processed AMZN successfully
# Processed NVDA successfully
# Processed TSLA successfully
# Processed AAPL successfully
# Processed AVGO successfully
# Processed MSFT successfully
# Processed BRK-B successfully
# Processed SPY successfully
# Processed XOM successfully
# Processed V successfully
# Processed UNH successfully
# Processed NVO successfully
# Processed LLY successfully
# Processed JPM successfully
# Processed WMT successfully
# Processed ORCL successfully
# Processed HD successfully
# Processed MA successfully
# Processed NFLX successfully
# Processed RCIT successfully
# Processed COST successfully
# Processed PG successfully
# Processed TMUS successfully
# Processed CVX successfully
# Processed CRM successfully
# Processed BAC successfully
# Processed JNJ successfully
# Processed SAP successfully
# Processed ABBV successfully
# Processed KO successfully
# Processed ASML successfully
# Processed TM successfully
# Processed ACN successfully
# Processed WFC successfully
# Processed CSCO successfully
# Processed MRK successfully
# Processed ADBE successfully
# Processed LIN successfully
# Processed MCD successfully
# Processed PEP successfully
# Processed MS successfully
# Processed BX successfully
# Processed AMD successfully
# Processed PM successfully
# Processed NVS successfully
# Processed AXP successfully
# Processed BABA successfully
# Processed NOW successfully
# Processed DIS successfully
# Processed QQQ successfully
# Processed GE successfully
# Processed SHEL successfully
# Processed ABT successfully
# Processed AZN successfully
# Processed TMO successfully
# Processed IBM successfully
# Processed ISRG successfully
# Processed INTU successfully
# Processed TXN successfully
# Processed GS successfully
# Processed QCOM successfully
# Processed CAT successfully
# Processed VZ successfully
# Processed HSBC successfully
# Processed RY successfully
# Processed BKNG successfully
# Processed DHR successfully
# Processed PDD successfully
# Processed CMCSA successfully
# Processed FMX successfully
# Processed T successfully
# Processed NEE successfully
# Processed RTX successfully
# Processed HDB successfully
# Processed LOW successfully
# Processed SPGI successfully
# Processed UBER successfully
# Processed BLK successfully
# Processed PGR successfully
# Processed AMGN successfully
# Processed UNP successfully
# Processed HON successfully
# Processed PLTR successfully
# Processed SYK successfully
# Processed SCHW successfully
# Processed UL successfully
# Processed ETN successfully
# Processed SHOP successfully
# Processed TTE successfully
# Processed AMAT successfully
# Processed PFE successfully
# Processed TJX successfully
# Processed ARM successfully
# Processed COP successfully
# Processed BHP successfully
# Processed MUFG successfully
# Processed KKR successfully
# Processed C successfully
# Processed RTNTF successfully
# Processed ADP successfully
# Processed LMT successfully
# Processed PANW successfully
# Processed BSX successfully
# Processed SNY successfully
# Processed FI successfully
# Processed ANET successfully
# Processed VRTX successfully
# Processed EADSY successfully
# Processed SBUX successfully
# Processed UPS successfully
# Processed CB successfully
# Processed NKE successfully
# Processed BMY successfully
# Processed BUD successfully
# Processed SONY successfully
# Processed MMC successfully
# Processed PLD successfully
# Processed MDT successfully
# Processed MU successfully
# Processed GILD successfully
# Processed DE successfully
# Processed INTC successfully
# Processed BA successfully
# Processed RIO successfully
# Processed ADI successfully
# Processed TD successfully
# Processed SO successfully
# Processed UBS successfully
# Processed IBN successfully
# Processed MO successfully
# Processed AIQUY successfully
# Processed SHW successfully
# Processed APP successfully
# Processed MELI successfully
# Processed SPOT successfully
# Processed GEV successfully
# Processed AMT successfully
# Processed ENB successfully
# Processed ELV successfully
# Processed DELL successfully
# Processed APO successfully
# Processed SMFG successfully
# Processed LRCX successfully
# Processed TT successfully
# Processed INFY successfully
# Processed CI successfully
# Processed ICE successfully
# Processed PH successfully
# Processed WM successfully
# Processed EQIX successfully
# Processed CTAS successfully
# Processed PBR successfully
# Processed DUK successfully
# Processed HCA successfully
# Processed PYPL successfully
# Processed WELL successfully
# Processed MCO successfully
# Processed MDLZ successfully
# Processed ABNB successfully
# Processed APH successfully
# Processed BN successfully
# Processed RELX successfully
# Processed CRWD successfully
# Processed KLAC successfully
# Processed REGN successfully
# Processed AON successfully
# Processed CMG successfully
# Processed PNC successfully
# Processed CME successfully
# Processed MSI successfully
# Processed BTI successfully
# Processed SNPS successfully
# Processed CFRUY successfully
# Processed ZTS successfully
# Processed ITW successfully
# Processed USB successfully
# Processed RACE successfully
# Processed GD successfully
# Processed SCCO successfully
# Processed CDNS successfully
# Processed EOG successfully
# Processed MAR successfully
# Processed COIN successfully
# Processed BP successfully
# Processed IBKR successfully
# Processed MCK successfully
# Processed MRVL successfully
# Processed CL successfully
# Processed SAN successfully
# Processed TRI successfully
# Processed FDX successfully
# Processed SHECY successfully
# Processed CNQ successfully
# Processed MMM successfully
# Processed EMR successfully
# Processed DASH successfully
# Processed FTNT successfully
# Processed NOC successfully
# Processed MSTR successfully
# Processed APD successfully
# Processed TGT successfully
# Processed CEG successfully
# Processed CP successfully
# Processed COF successfully
# Processed CNI successfully
# Processed ORLY successfully
# Processed GSK successfully
# Processed TDG successfully
# Processed ECL successfully
# Processed WDAY successfully
# Processed BMO successfully
# Processed WMB successfully
# Processed CSX successfully
# Processed SPG successfully
# Processed BNS successfully
# Processed EPD successfully
# Processed NU successfully
# Processed CRH successfully
# Processed EQNR successfully
# Processed CVS successfully
# Processed RSG successfully
# Processed DEO successfully
# Processed AJG successfully
# Processed CARR successfully
# Processed BDX successfully
# Processed RCL successfully
# Processed GM successfully
# Processed TOELY successfully
# Processed GLD successfully
# Processed ANZGY successfully
# Processed ADSK successfully
# Processed AFL successfully
# Processed OKE successfully
# Processed TEAM successfully
# Processed TFC successfully
# Processed DLR successfully
# Processed FCX successfully
# Processed NGG successfully
# Processed MFG successfully
# Processed CM successfully
# Processed MBGYY successfully
# Processed HLT successfully
# Processed KMI successfully
# Processed SLB successfully
# Processed NSC successfully
# Processed PSA successfully
# Processed TTD successfully
# Processed TRV successfully
# Processed ROP successfully
# Processed ET successfully
# Processed GLNCY successfully
# Processed PCAR successfully
# Processed SE successfully
# Processed JD successfully
# Processed GWW successfully
# Processed BBVA successfully
# Processed MFC successfully
# Processed SRE successfully
# Processed JCI successfully
# Processed MET successfully
# Processed NXPI successfully
# Processed BK successfully
# Processed ITUB successfully
# Processed CHTR successfully
# Processed PCG successfully
# Processed AMP successfully
# Processed FICO successfully
# Processed URI successfully
# Processed CPRT successfully
# Processed PSX successfully
# Processed DHI successfully
# Processed PTCAY successfully
# Processed NTES successfully
# Processed ARES successfully
# Processed FANG successfully
# Processed AZO successfully
# Processed AEP successfully
# Processed CTA-PA successfully
# Processed ALL successfully
# Processed PAYX successfully
# Processed SU successfully
# Processed TRP successfully
# Processed MNST successfully
# Processed MPC successfully
# Processed SQ successfully
# Processed BAESY successfully
# Processed GBTC successfully
# Processed BCS successfully
# Processed O successfully
# Processed ING successfully
# Processed CMI successfully
# Processed D successfully
# Processed VST successfully
# Processed FIS successfully
# Processed MPLX successfully
# Processed LNG successfully
# Processed WCN successfully
# Processed PWR successfully
# Processed CODYY successfully
# Processed IAU successfully
# Processed AIG successfully
# Processed OXY successfully
# Processed FAST successfully
# Processed FLUT successfully
# Processed NEM successfully
# Processed ROST successfully
# Processed COR successfully
# Processed AMX successfully
# Processed MSCI successfully
# Processed E successfully
# Processed LHX successfully
# Processed ODFL successfully
# Processed HWM successfully
# Processed KVUE successfully
# Processed LEN successfully
# Processed CCI successfully
# Processed AXON successfully
# Processed PRU successfully
# Processed HES successfully
# Processed KMB successfully
# Processed NDAQ successfully
# Processed VRT successfully
# Processed F successfully
# Processed TEL successfully
# Processed DFS successfully
# Processed VLO successfully
# Processed AME successfully
# Processed CPNG successfully
# Processed PEG successfully
# Processed BMWKY successfully
# Processed STZ successfully
# Processed DDOG successfully
# Processed LYG successfully
# Processed KDP successfully
# Processed CRARY successfully
# Processed CAIXY successfully
# Processed EA successfully
# Processed TAK successfully
# Processed DNZOY successfully
# Processed VALE successfully
# Processed HLN successfully
# Processed ALC successfully
# Processed TRGP successfully
# Processed SNOW successfully
# Processed ATEYY successfully
# Processed NWG successfully
# Processed KR successfully
# Processed SVNDY successfully
# Processed DAL successfully
# Processed IT successfully
# Processed BKR successfully
# Processed FERG successfully
# Processed HMC successfully
# Processed IR successfully
# Processed XEL successfully
# Processed GRMN successfully
# Processed LULU successfully
# Processed GLW successfully
# Processed CBRE successfully
# Processed VRSK successfully
# Processed EW successfully
# Processed OTIS successfully
# Processed EXC successfully
# Processed AEM successfully
# Processed OLCLY successfully
# Processed STLA successfully
# Processed IMO successfully
# Processed CTVA successfully
# Processed CTSH successfully
# Processed TCOM successfully
# Processed YUM successfully
# Processed KHC successfully
# Processed ACGL successfully
# Processed PPERY successfully
# Processed VMC successfully
# Processed WTKWY successfully
# Processed EXR successfully
# Processed SYY successfully
# Processed DIA successfully
# Processed MLM successfully
# Processed GEHC successfully
# Processed A successfully
# Processed HPQ successfully
# Processed MTB successfully
# Processed WIT successfully
# Processed LVS successfully
# Processed CCEP successfully
# Processed IQV successfully
# Processed HSY successfully
# Processed GIS successfully
# Processed DKILY successfully
# Processed HUBS successfully
# Processed ABEV successfully
# Processed SLF successfully
# Processed VEEV successfully
# Processed RBLX successfully
# Processed NUE successfully
# Processed IRM successfully
# Processed IDXX successfully
# Processed RMD successfully
# Processed HIG successfully
# Processed DD successfully
# Processed ARGX successfully
# Processed OWL successfully
# Processed MCHP successfully
# Processed WAB successfully
# Processed BSBR successfully
# Processed ED successfully
# Processed AVB successfully
# Processed HUM successfully
# Processed VICI successfully
# Processed MDY successfully
# Processed DB successfully
# Processed CCL successfully
# Processed RJF successfully
# Processed EIX successfully
# Processed ROK successfully
# Processed ETR successfully
# Processed GWLIF successfully
# Processed HEI successfully
# Processed ANYYY successfully
# Processed MRAAY successfully
# Processed BRO successfully
# Processed FRFHF successfully
# Processed FITB successfully
# Processed WTW successfully
# Processed TTWO successfully
# Processed TPL successfully
# Processed WEC successfully
# Processed ALNY successfully
# Processed DOW successfully
# Processed EFX successfully
# Processed FCNCA successfully
# Processed QSR successfully
# Processed UAL successfully
# Processed DXCM successfully
# Processed ZS successfully
# Processed NET successfully
# Processed CHT successfully
# Processed BIDU successfully
# Processed EBAY successfully
# Processed GPN successfully
# Processed GOLD successfully
# Processed TSCO successfully
# Processed LYV successfully
# Processed XYL successfully
# Processed WDS successfully
# Processed CSGP successfully
# Processed EQR successfully
# Processed DSCSY successfully
# Processed ANSS successfully
# Processed CNC successfully
# Processed PPRUY successfully
# Processed CVNA successfully
# Processed TW successfully
# Processed CVE successfully
# Processed CUK successfully
# Processed CAH successfully
# Processed PPG successfully
# Processed HOOD successfully
# Processed FER successfully
# Processed NVR successfully
# Processed STT successfully
# Processed OEZVY successfully
# Processed ON successfully
# Processed K successfully
# Processed MPWR successfully
# Processed DOV successfully
# Processed IOT successfully
# Processed RKT successfully
# Processed WPM successfully
# Processed VTR successfully
# Processed LYB successfully
# Processed HPE successfully
# Processed NVZMY successfully
# Processed ERIC successfully
# Processed DECK successfully
# Processed SW successfully
# Processed PHM successfully
# Processed BR successfully
# Processed CHD successfully
# Processed AWK successfully
# Processed TROW successfully
# Processed HAL successfully
# Processed FUJIY successfully
# Processed FTV successfully
# Processed CQP successfully
# Processed PUBGY successfully
# Processed KEYS successfully
# Processed EQT successfully
# Processed ADM successfully
# Processed DVN successfully
# Processed CPAY successfully
# Processed NTDTY successfully
# Processed GDDY successfully
# Processed TYL successfully
# Processed SYF successfully
# Processed VLTO successfully
# Processed HBAN successfully
# Processed PPL successfully
# Processed TEF successfully
# Processed MTD successfully
# Processed FANUY successfully
# Processed BCE successfully
# Processed DTE successfully
# Processed RYAAY successfully
# Processed ZM successfully
# Processed IX successfully
# Processed AEE successfully
# Processed PHG successfully
# Processed GIB successfully
# Processed ROL successfully
# Processed KB successfully
# Processed BEKE successfully
# Processed NOK successfully
# Processed PBA successfully
# Processed BBD successfully
# Processed FE successfully
# Processed RF successfully
# Processed LI successfully
# Processed SBAC successfully
# Processed NTAP successfully
# Processed BAM successfully
# Processed CINF successfully
# Processed TPG successfully
# Processed HUBB successfully
# Processed CDW successfully
# Processed CCJ successfully
# Processed LPLA successfully
# Processed BNTX successfully
# Processed DIDIY successfully
# Processed TECK successfully
# Processed BIIB successfully
# Processed TOST successfully
# Processed TSN successfully
# Processed EXPE successfully
# Processed EME successfully
# Processed VOD successfully
# Processed GFS successfully
# Processed NTR successfully
# Processed WST successfully
# Processed WRB successfully
# Processed HDELY successfully
# Processed EL successfully
# Processed ES successfully
# Processed TU successfully
# Processed ATO successfully
# Processed FNV successfully
# Processed WY successfully
# Processed WBD successfully
# Processed PTC successfully
# Processed STM successfully
# Processed EXE successfully
# Processed ZBH successfully
# Processed RDDT successfully
# Processed IFF successfully
# Processed FTS successfully
# Processed TDY successfully
# Processed MKL successfully
# Processed PUK successfully
# Processed KSPI successfully
# Processed STE successfully
# Processed LII successfully
# Processed ILMN successfully
# Processed WDC successfully
# Processed LDOS successfully
# Processed SMPNY successfully
# Processed ERIE successfully
# Processed WAT successfully
# Processed NTRS successfully
# Processed PKG successfully
# Processed EJPRY successfully
# Processed WSO successfully
# Processed STLD successfully
# Processed ASX successfully
# Processed CBOE successfully
# Processed NJDCY successfully
# Processed INVH successfully
# Processed BGNE successfully
# Processed SNWV successfully
# Processed CLX successfully
# Processed FSLR successfully
# Processed MDB successfully
# Processed TS successfully
# Processed CFG successfully
# Processed STX successfully
# Processed CMS successfully
# Processed ESS successfully
# Processed UI successfully
# Processed BLDR successfully
# Processed FOXA successfully
# Processed CJPRY successfully
# Processed CSL successfully
# Processed DRI successfully
# Processed MKC successfully
# Processed IP successfully
# Processed CNP successfully
# Processed BBY successfully
# Processed COO successfully
# Processed ZBRA successfully
# Processed MT successfully
# Processed LH successfully
# Processed PFG successfully
# Processed VIK successfully
# Processed LUV successfully
# Processed YAHOY successfully
# Processed BAH successfully
# Processed DKNG successfully
# Processed IHG successfully
# Processed CHKP successfully
# Processed PINS successfully
# Processed MAA successfully
# Processed BF-A successfully
# Processed SHG successfully
# Processed RCI successfully
# Processed NTRA successfully
# Processed GRAB successfully
# Processed KEY successfully
# Processed CTRA successfully
# Processed RYAN successfully
# Processed OMC successfully
# Processed TRU successfully
# Processed SNA successfully
# Processed NRG successfully
# Processed SGSOY successfully
# Processed TEVA successfully
# Processed NTNX successfully
# Processed PODD successfully
# Processed FDS successfully
# Processed BALL successfully
# Processed ARE successfully
# Processed JBHT successfully
# Processed YUMC successfully
# Processed TME successfully
# Processed SSNC successfully
# Processed HOLX successfully
# Processed GEN successfully
# Processed AER successfully
# Processed L successfully
# Processed DGX successfully
# Processed SNAP successfully
# Processed CG successfully
# Processed VRSN successfully
# Processed SYM successfully
# Processed AFRM successfully
# Processed J successfully
# Processed ULTA successfully
# Processed NMR successfully
# Processed GFL successfully
# Processed PNR successfully
# Processed UMC successfully
# Processed IEX successfully
# Processed CRBG successfully
# Processed RPM successfully
# Processed BURL successfully
# Processed RBA successfully
# Processed ZTO successfully
# Processed KOF successfully
# Processed GPC successfully
# Processed TRMB successfully
# Processed EXPD successfully
# Processed NI successfully
# Processed XPO successfully
# Processed WMG successfully
# Processed MOH successfully
# Processed ONON successfully
# Processed NWSA successfully
# Processed RS successfully
# Processed ZG successfully
# Processed KIM successfully
# Processed MAS successfully
# Processed ALGN successfully
# Processed BEP successfully
# Processed SUI successfully
# Processed MANH successfully
# Processed TER successfully
# Processed UDR successfully
# Processed FNF successfully
# Processed DG successfully
# Processed WSM successfully
# Processed OC successfully
# Processed BAX successfully
# Processed CAVA successfully
# Processed EC successfully

# %% [markdown]
# # Perform RAG

# %%
# Initialize Pinecone
pc = Pinecone(api_key=userdata.get("PINECONE_API_KEY"),)

# Connect to your Pinecone index
pinecone_index = pc.Index('stocks')

# %%
query = "What are some companies that manufacture consumer hardware?"

# %%
raw_query_embedding = get_huggingface_embeddings(query)

# %%
top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=10, include_metadata=True, namespace='stock-descriptions')

# %%
top_matches
# Out:
# {'matches': [{'id': '651e344c-2faf-4fd5-9032-0cf11cdaf2ed',
#               'metadata': {'Business Summary': 'Honeywell International Inc. '
#                                                'engages in the aerospace '
#                                                'technologies, building '
#                                                'automation, energy and '
#                                                'sustainable solutions, and '
#                                                'industrial automation '
#                                                'businesses in the United '
#                                                'States, Europe, and '
#                                                "internationally. The company's "
#                                                'Aerospace segment offers '
#                                                'auxiliary power units, '
#                                                'propulsion engines, integrated '
#                                                'avionics, environmental '
#                                                'control and electric power '
#                                                'systems, engine controls, '
#                                                'flight safety, communications, '
#                                                'navigation hardware, data and '
#                                                'software applications, radar '
#                                                'and surveillance systems, '
#                                                'aircraft lighting, advanced '
#                                                'systems and instruments, '
#                                                'satellite and space '
#                                                'components, and aircraft '
#                                                'wheels and brakes; spare '
#                                                'parts; repair, overhaul, and '
#                                                'maintenance services; and '
#                                                'thermal systems, as well as '
#                                                'wireless connectivity '
#                                                'services. Its Honeywell '
#                                                'Building Technologies segment '
#                                                'provides software applications '
#                                                'for building control and '
#                                                'optimization; sensors, '
#                                                'switches, control systems, and '
#                                                'instruments for energy '
#                                                'management; access control; '
#                                                'video surveillance; fire '
#                                                'products; and installation, '
#                                                'maintenance, and upgrades of '
#                                                "systems. The company's "
#                                                'Performance Materials and '
#                                                'Technologies segment offers '
#                                                'automation control, '
#                                                'instrumentation, and software '
#                                                'and related services; '
#                                                'catalysts and adsorbents, '
#                                                'equipment, and consulting; and '
#                                                'materials to manufacture end '
#                                                'products, such as '
#                                                'bullet-resistant armor, nylon, '
#                                                'computer chips, and '
#                                                'pharmaceutical packaging, as '
#                                                'well as provides materials '
#                                                'based on hydrofluoro-olefin '
#                                                'technology. Its Safety and '
#                                                'Productivity Solutions segment '
#                                                'provides personal protective '
#                                                'equipment, apparel, gear, and '
#                                                'footwear; gas detection '
#                                                'technology; custom-engineered '
#                                                'sensors, switches, and '
#                                                'controls for sensing and '
#                                                'productivity solution; '
#                                                'cloud-based notification and '
#                                                'emergency messaging; mobile '
#                                                'devices and software; '
#                                                'custom-engineered sensors, '
#                                                'switches, and controls; and '
#                                                'data and asset management '
#                                                'productivity solutions. '
#                                                'Honeywell International Inc. '
#                                                'was founded in 1885 and is '
#                                                'headquartered in Charlotte, '
#                                                'North Carolina.',
#                            'City': 'Charlotte',
#                            'Country': 'United States',
#                            'Industry': 'Conglomerates',
#                            'Name': 'Honeywell International Inc.',
#                            'Sector': 'Industrials',
#                            'State': 'NC',
#                            'Ticker': 'HON',
#                            'text': 'Honeywell International Inc. engages in '
#                                    'the aerospace technologies, building '
#                                    'automation, energy and sustainable '
#                                    'solutions, and industrial automation '
#                                    'businesses in the United States, Europe, '
#                                    "and internationally. The company's "
#                                    'Aerospace segment offers auxiliary power '
#                                    'units, propulsion engines, integrated '
#                                    'avionics, environmental control and '
#                                    'electric power systems, engine controls, '
#                                    'flight safety, communications, navigation '
#                                    'hardware, data and software applications, '
#                                    'radar and surveillance systems, aircraft '
#                                    'lighting, advanced systems and '
#                                    'instruments, satellite and space '
#                                    'components, and aircraft wheels and '
#                                    'brakes; spare parts; repair, overhaul, and '
#                                    'maintenance services; and thermal systems, '
#                                    'as well as wireless connectivity services. '
#                                    'Its Honeywell Building Technologies '
#                                    'segment provides software applications for '
#                                    'building control and optimization; '
#                                    'sensors, switches, control systems, and '
#                                    'instruments for energy management; access '
#                                    'control; video surveillance; fire '
#                                    'products; and installation, maintenance, '
#                                    "and upgrades of systems. The company's "
#                                    'Performance Materials and Technologies '
#                                    'segment offers automation control, '
#                                    'instrumentation, and software and related '
#                                    'services; catalysts and adsorbents, '
#                                    'equipment, and consulting; and materials '
#                                    'to manufacture end products, such as '
#                                    'bullet-resistant armor, nylon, computer '
#                                    'chips, and pharmaceutical packaging, as '
#                                    'well as provides materials based on '
#                                    'hydrofluoro-olefin technology. Its Safety '
#                                    'and Productivity Solutions segment '
#                                    'provides personal protective equipment, '
#                                    'apparel, gear, and footwear; gas detection '
#                                    'technology; custom-engineered sensors, '
#                                    'switches, and controls for sensing and '
#                                    'productivity solution; cloud-based '
#                                    'notification and emergency messaging; '
#                                    'mobile devices and software; '
#                                    'custom-engineered sensors, switches, and '
#                                    'controls; and data and asset management '
#                                    'productivity solutions. Honeywell '
#                                    'International Inc. was founded in 1885 and '
#                                    'is headquartered in Charlotte, North '
#                                    'Carolina.'},
#               'score': 0.452476263,
#               'values': []},
#              {'id': '729902e2-1788-4fce-9d9b-1e45ab54f0fc',
#               'metadata': {'Business Summary': 'Applied Materials, Inc. '
#                                                'engages in the provision of '
#                                                'manufacturing equipment, '
#                                                'services, and software to the '
#                                                'semiconductor, display, and '
#                                                'related industries. The '
#                                                'company operates through three '
#                                                'segments: Semiconductor '
#                                                'Systems, Applied Global '
#                                                'Services, and Display and '
#                                                'Adjacent Markets. The '
#                                                'Semiconductor Systems segment '
#                                                'develops, manufactures, and '
#                                                'sells various manufacturing '
#                                                'equipment that is used to '
#                                                'fabricate semiconductor chips '
#                                                'or integrated circuits. This '
#                                                'segment also offers various '
#                                                'technologies, including '
#                                                'epitaxy, ion implantation, '
#                                                'oxidation/nitridation, rapid '
#                                                'thermal processing, physical '
#                                                'vapor deposition, chemical '
#                                                'vapor deposition, chemical '
#                                                'mechanical planarization, '
#                                                'electrochemical deposition, '
#                                                'atomic layer deposition, '
#                                                'etching, and selective '
#                                                'deposition and removal, as '
#                                                'well as metrology and '
#                                                'inspection tools. The Applied '
#                                                'Global Services segment '
#                                                'provides integrated solutions '
#                                                'to optimize equipment and fab '
#                                                'performance and productivity '
#                                                'comprising spares, upgrades, '
#                                                'services, remanufactured '
#                                                'earlier generation equipment, '
#                                                'and factory automation '
#                                                'software for semiconductor, '
#                                                'display, and other products. '
#                                                'The Display and Adjacent '
#                                                'Markets segment offers '
#                                                'products for manufacturing '
#                                                'liquid crystal displays; '
#                                                'organic light-emitting diodes; '
#                                                'and other display technologies '
#                                                'for TVs, monitors, laptops, '
#                                                'personal computers, electronic '
#                                                'tablets, smart phones, and '
#                                                'other consumer-oriented '
#                                                'devices. It operates in the '
#                                                'United States, China, Korea, '
#                                                'Taiwan, Japan, Southeast Asia, '
#                                                'and Europe. The company was '
#                                                'incorporated in 1967 and is '
#                                                'headquartered in Santa Clara, '
#                                                'California.',
#                            'City': 'Santa Clara',
#                            'Country': 'United States',
#                            'Industry': 'Semiconductor Equipment & Materials',
#                            'Name': 'Applied Materials, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'CA',
#                            'Ticker': 'AMAT',
#                            'text': 'Applied Materials, Inc. engages in the '
#                                    'provision of manufacturing equipment, '
#                                    'services, and software to the '
#                                    'semiconductor, display, and related '
#                                    'industries. The company operates through '
#                                    'three segments: Semiconductor Systems, '
#                                    'Applied Global Services, and Display and '
#                                    'Adjacent Markets. The Semiconductor '
#                                    'Systems segment develops, manufactures, '
#                                    'and sells various manufacturing equipment '
#                                    'that is used to fabricate semiconductor '
#                                    'chips or integrated circuits. This segment '
#                                    'also offers various technologies, '
#                                    'including epitaxy, ion implantation, '
#                                    'oxidation/nitridation, rapid thermal '
#                                    'processing, physical vapor deposition, '
#                                    'chemical vapor deposition, chemical '
#                                    'mechanical planarization, electrochemical '
#                                    'deposition, atomic layer deposition, '
#                                    'etching, and selective deposition and '
#                                    'removal, as well as metrology and '
#                                    'inspection tools. The Applied Global '
#                                    'Services segment provides integrated '
#                                    'solutions to optimize equipment and fab '
#                                    'performance and productivity comprising '
#                                    'spares, upgrades, services, remanufactured '
#                                    'earlier generation equipment, and factory '
#                                    'automation software for semiconductor, '
#                                    'display, and other products. The Display '
#                                    'and Adjacent Markets segment offers '
#                                    'products for manufacturing liquid crystal '
#                                    'displays; organic light-emitting diodes; '
#                                    'and other display technologies for TVs, '
#                                    'monitors, laptops, personal computers, '
#                                    'electronic tablets, smart phones, and '
#                                    'other consumer-oriented devices. It '
#                                    'operates in the United States, China, '
#                                    'Korea, Taiwan, Japan, Southeast Asia, and '
#                                    'Europe. The company was incorporated in '
#                                    '1967 and is headquartered in Santa Clara, '
#                                    'California.'},
#               'score': 0.44577679,
#               'values': []},
#              {'id': '6756a11b-04c5-4476-b146-5e6731baed29',
#               'metadata': {'Business Summary': 'Advanced Micro Devices, Inc. '
#                                                'operates as a semiconductor '
#                                                'company worldwide. It operates '
#                                                'through Data Center, Client, '
#                                                'Gaming, and Embedded segments. '
#                                                'The company offers x86 '
#                                                'microprocessors and graphics '
#                                                'processing units (GPUs) as an '
#                                                'accelerated processing unit, '
#                                                'chipsets, data center, and '
#                                                'professional GPUs; and '
#                                                'embedded processors, and '
#                                                'semi-custom system-on-chip '
#                                                '(SoC) products, microprocessor '
#                                                'and SoC development services '
#                                                'and technology, data '
#                                                'processing unites, field '
#                                                'programmable gate arrays '
#                                                '(FPGA), and adaptive SoC '
#                                                'products. It provides '
#                                                'processors under the AMD '
#                                                'Ryzen, AMD Ryzen PRO, Ryzen '
#                                                'Threadripper, Ryzen '
#                                                'Threadripper PRO, AMD Athlon, '
#                                                'AMD Athlon PRO, and AMD PRO '
#                                                'A-Series brand names; graphics '
#                                                'under the AMD Radeon graphics '
#                                                'and AMD Embedded Radeon '
#                                                'graphics; and professional '
#                                                'graphics under the AMD Radeon '
#                                                'Pro graphics brand name. In '
#                                                'addition, the company offers '
#                                                'data center graphics under the '
#                                                'Radeon Instinct and Radeon PRO '
#                                                'V-series brands, as well as '
#                                                'servers under the AMD Instinct '
#                                                'accelerators brand; server '
#                                                'microprocessors under the AMD '
#                                                'EPYC brands; low power '
#                                                'solutions under the AMD '
#                                                'Athlon, AMD Geode, AMD Ryzen, '
#                                                'AMD EPYC, AMD R-Series, and '
#                                                'G-Series brands; FPGA products '
#                                                'under the Virtex-6, Virtex-7, '
#                                                'Virtex UltraScale+, Kintex-7, '
#                                                'Kintex UltraScale, Kintex '
#                                                'UltraScale+, Artix-7, Artix '
#                                                'UltraScale+, Spartan-6, and '
#                                                'Spartan-7 brands; adaptive '
#                                                'SOCs under the Zynq-7000, Zynq '
#                                                'UltraScale+ MPSoC, Zynq '
#                                                'UltraScale+ RFSoCs, Versal '
#                                                'HBM, Versal Premium, Versal '
#                                                'Prime, Versal AI Core, Versal '
#                                                'AI Edge, Vitis, and Vivado '
#                                                'brands; and compute and '
#                                                'network acceleration board '
#                                                'products under the Alveo '
#                                                'brand. It serves original '
#                                                'equipment and design '
#                                                'manufacturers, public cloud '
#                                                'service providers, system '
#                                                'integrators, independent '
#                                                'distributors, and add-in-board '
#                                                'manufacturers through its '
#                                                'direct sales force, and sales '
#                                                'representatives. Advanced '
#                                                'Micro Devices, Inc. was '
#                                                'incorporated in 1969 and is '
#                                                'headquartered in Santa Clara, '
#                                                'California.',
#                            'City': 'Santa Clara',
#                            'Country': 'United States',
#                            'Industry': 'Semiconductors',
#                            'Name': 'Advanced Micro Devices, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'CA',
#                            'Ticker': 'AMD',
#                            'text': 'Advanced Micro Devices, Inc. operates as a '
#                                    'semiconductor company worldwide. It '
#                                    'operates through Data Center, Client, '
#                                    'Gaming, and Embedded segments. The company '
#                                    'offers x86 microprocessors and graphics '
#                                    'processing units (GPUs) as an accelerated '
#                                    'processing unit, chipsets, data center, '
#                                    'and professional GPUs; and embedded '
#                                    'processors, and semi-custom system-on-chip '
#                                    '(SoC) products, microprocessor and SoC '
#                                    'development services and technology, data '
#                                    'processing unites, field programmable gate '
#                                    'arrays (FPGA), and adaptive SoC products. '
#                                    'It provides processors under the AMD '
#                                    'Ryzen, AMD Ryzen PRO, Ryzen Threadripper, '
#                                    'Ryzen Threadripper PRO, AMD Athlon, AMD '
#                                    'Athlon PRO, and AMD PRO A-Series brand '
#                                    'names; graphics under the AMD Radeon '
#                                    'graphics and AMD Embedded Radeon graphics; '
#                                    'and professional graphics under the AMD '
#                                    'Radeon Pro graphics brand name. In '
#                                    'addition, the company offers data center '
#                                    'graphics under the Radeon Instinct and '
#                                    'Radeon PRO V-series brands, as well as '
#                                    'servers under the AMD Instinct '
#                                    'accelerators brand; server microprocessors '
#                                    'under the AMD EPYC brands; low power '
#                                    'solutions under the AMD Athlon, AMD Geode, '
#                                    'AMD Ryzen, AMD EPYC, AMD R-Series, and '
#                                    'G-Series brands; FPGA products under the '
#                                    'Virtex-6, Virtex-7, Virtex UltraScale+, '
#                                    'Kintex-7, Kintex UltraScale, Kintex '
#                                    'UltraScale+, Artix-7, Artix UltraScale+, '
#                                    'Spartan-6, and Spartan-7 brands; adaptive '
#                                    'SOCs under the Zynq-7000, Zynq UltraScale+ '
#                                    'MPSoC, Zynq UltraScale+ RFSoCs, Versal '
#                                    'HBM, Versal Premium, Versal Prime, Versal '
#                                    'AI Core, Versal AI Edge, Vitis, and Vivado '
#                                    'brands; and compute and network '
#                                    'acceleration board products under the '
#                                    'Alveo brand. It serves original equipment '
#                                    'and design manufacturers, public cloud '
#                                    'service providers, system integrators, '
#                                    'independent distributors, and add-in-board '
#                                    'manufacturers through its direct sales '
#                                    'force, and sales representatives. Advanced '
#                                    'Micro Devices, Inc. was incorporated in '
#                                    '1969 and is headquartered in Santa Clara, '
#                                    'California.'},
#               'score': 0.443927258,
#               'values': []},
#              {'id': '6611eed2-e71d-4c3e-ba81-2928dcd6dafe',
#               'metadata': {'Business Summary': 'Broadcom Inc. designs, '
#                                                'develops, and supplies various '
#                                                'semiconductor devices with a '
#                                                'focus on complex digital and '
#                                                'mixed signal complementary '
#                                                'metal oxide semiconductor '
#                                                'based devices and analog III-V '
#                                                'based products worldwide. The '
#                                                'company operates in two '
#                                                'segments, Semiconductor '
#                                                'Solutions and Infrastructure '
#                                                'Software. It provides set-top '
#                                                'box system-on-chips (SoCs); '
#                                                'cable, digital subscriber '
#                                                'line, and passive optical '
#                                                'networking central '
#                                                'office/consumer premise '
#                                                'equipment SoCs; wireless local '
#                                                'area network access point '
#                                                'SoCs; Ethernet switching and '
#                                                'routing custom silicon '
#                                                'solutions; '
#                                                'serializer/deserializer '
#                                                'application specific '
#                                                'integrated circuits; optical '
#                                                'and copper, and physical layer '
#                                                'devices; and fiber optic '
#                                                'components and RF '
#                                                'semiconductor devices. The '
#                                                'company also offers RF front '
#                                                'end modules and filter; Wi-Fi, '
#                                                'Bluetooth, and global '
#                                                'positioning system/global '
#                                                'navigation satellite system '
#                                                'SoCs; custom touch '
#                                                'controllers; inductive '
#                                                'charging; attached small '
#                                                'computer system interface, and '
#                                                'redundant array of independent '
#                                                'disks controllers and '
#                                                'adapters; peripheral component '
#                                                'interconnect express; fiber '
#                                                'channel host bus adapters; '
#                                                'read channel based SoCs; '
#                                                'custom flash controllers; '
#                                                'preamplifiers; optocouplers, '
#                                                'industrial fiber optics, and '
#                                                'motion control encoders and '
#                                                'subsystems; light emitting '
#                                                'diode, ethernet PHYs, switch '
#                                                'ICs, and camera '
#                                                'microcontrollers. Its products '
#                                                'are used in various '
#                                                'applications, including '
#                                                'enterprise and data center '
#                                                'networking, home connectivity, '
#                                                'set-top boxes, broadband '
#                                                'access, telecommunication '
#                                                'equipment, smartphones and '
#                                                'base stations, data center '
#                                                'servers and storage systems, '
#                                                'factory automation, power '
#                                                'generation and alternative '
#                                                'energy systems, and electronic '
#                                                'displays. Broadcom Inc. was '
#                                                'founded in 1961 and is '
#                                                'headquartered in Palo Alto, '
#                                                'California.',
#                            'City': 'Palo Alto',
#                            'Country': 'United States',
#                            'Industry': 'Semiconductors',
#                            'Name': 'Broadcom Inc.',
#                            'Sector': 'Technology',
#                            'State': 'CA',
#                            'Ticker': 'AVGO',
#                            'text': 'Broadcom Inc. designs, develops, and '
#                                    'supplies various semiconductor devices '
#                                    'with a focus on complex digital and mixed '
#                                    'signal complementary metal oxide '
#                                    'semiconductor based devices and analog '
#                                    'III-V based products worldwide. The '
#                                    'company operates in two segments, '
#                                    'Semiconductor Solutions and Infrastructure '
#                                    'Software. It provides set-top box '
#                                    'system-on-chips (SoCs); cable, digital '
#                                    'subscriber line, and passive optical '
#                                    'networking central office/consumer premise '
#                                    'equipment SoCs; wireless local area '
#                                    'network access point SoCs; Ethernet '
#                                    'switching and routing custom silicon '
#                                    'solutions; serializer/deserializer '
#                                    'application specific integrated circuits; '
#                                    'optical and copper, and physical layer '
#                                    'devices; and fiber optic components and RF '
#                                    'semiconductor devices. The company also '
#                                    'offers RF front end modules and filter; '
#                                    'Wi-Fi, Bluetooth, and global positioning '
#                                    'system/global navigation satellite system '
#                                    'SoCs; custom touch controllers; inductive '
#                                    'charging; attached small computer system '
#                                    'interface, and redundant array of '
#                                    'independent disks controllers and '
#                                    'adapters; peripheral component '
#                                    'interconnect express; fiber channel host '
#                                    'bus adapters; read channel based SoCs; '
#                                    'custom flash controllers; preamplifiers; '
#                                    'optocouplers, industrial fiber optics, and '
#                                    'motion control encoders and subsystems; '
#                                    'light emitting diode, ethernet PHYs, '
#                                    'switch ICs, and camera microcontrollers. '
#                                    'Its products are used in various '
#                                    'applications, including enterprise and '
#                                    'data center networking, home connectivity, '
#                                    'set-top boxes, broadband access, '
#                                    'telecommunication equipment, smartphones '
#                                    'and base stations, data center servers and '
#                                    'storage systems, factory automation, power '
#                                    'generation and alternative energy systems, '
#                                    'and electronic displays. Broadcom Inc. was '
#                                    'founded in 1961 and is headquartered in '
#                                    'Palo Alto, California.'},
#               'score': 0.435423911,
#               'values': []},
#              {'id': 'e30b8886-e202-4060-b32d-be2f37e3dd13',
#               'metadata': {'Business Summary': 'Texas Instruments Incorporated '
#                                                'designs, manufactures, and '
#                                                'sells semiconductors to '
#                                                'electronics designers and '
#                                                'manufacturers in the United '
#                                                'States and internationally. '
#                                                'The company operates through '
#                                                'Analog and Embedded Processing '
#                                                'segments. The Analog segment '
#                                                'offers power products to '
#                                                'manage power requirements '
#                                                'across various voltage levels, '
#                                                'including battery-management '
#                                                'solutions, DC/DC switching '
#                                                'regulators, AC/DC and isolated '
#                                                'controllers and converters, '
#                                                'power switches, linear '
#                                                'regulators, voltage '
#                                                'references, and lighting '
#                                                'products. This segment '
#                                                'provides signal chain products '
#                                                'that sense, condition, and '
#                                                'measure signals to allow '
#                                                'information to be transferred '
#                                                'or converted for further '
#                                                'processing and control, '
#                                                'including amplifiers, data '
#                                                'converters, interface '
#                                                'products, motor drives, '
#                                                'clocks, and logic and sensing '
#                                                'products. The Embedded '
#                                                'Processing segment offers '
#                                                'microcontrollers that are used '
#                                                'in electronic equipment; '
#                                                'digital signal processors for '
#                                                'mathematical computations; and '
#                                                'applications processors for '
#                                                'specific computing activity. '
#                                                'This segment offers products '
#                                                'for use in various markets, '
#                                                'such as industrial, '
#                                                'automotive, personal '
#                                                'electronics, communications '
#                                                'equipment, enterprise systems, '
#                                                'and calculators and other. It '
#                                                'provides DLP products '
#                                                'primarily for use in project '
#                                                'high-definition images; '
#                                                'calculators; and '
#                                                'application-specific '
#                                                'integrated circuits. The '
#                                                'company markets and sells its '
#                                                'semiconductor products through '
#                                                'direct sales and distributors, '
#                                                'as well as through its '
#                                                'website. Texas Instruments '
#                                                'Incorporated was founded in '
#                                                '1930 and is headquartered in '
#                                                'Dallas, Texas.',
#                            'City': 'Dallas',
#                            'Country': 'United States',
#                            'Industry': 'Semiconductors',
#                            'Name': 'Texas Instruments Incorporated',
#                            'Sector': 'Technology',
#                            'State': 'TX',
#                            'Ticker': 'TXN',
#                            'text': 'Texas Instruments Incorporated designs, '
#                                    'manufactures, and sells semiconductors to '
#                                    'electronics designers and manufacturers in '
#                                    'the United States and internationally. The '
#                                    'company operates through Analog and '
#                                    'Embedded Processing segments. The Analog '
#                                    'segment offers power products to manage '
#                                    'power requirements across various voltage '
#                                    'levels, including battery-management '
#                                    'solutions, DC/DC switching regulators, '
#                                    'AC/DC and isolated controllers and '
#                                    'converters, power switches, linear '
#                                    'regulators, voltage references, and '
#                                    'lighting products. This segment provides '
#                                    'signal chain products that sense, '
#                                    'condition, and measure signals to allow '
#                                    'information to be transferred or converted '
#                                    'for further processing and control, '
#                                    'including amplifiers, data converters, '
#                                    'interface products, motor drives, clocks, '
#                                    'and logic and sensing products. The '
#                                    'Embedded Processing segment offers '
#                                    'microcontrollers that are used in '
#                                    'electronic equipment; digital signal '
#                                    'processors for mathematical computations; '
#                                    'and applications processors for specific '
#                                    'computing activity. This segment offers '
#                                    'products for use in various markets, such '
#                                    'as industrial, automotive, personal '
#                                    'electronics, communications equipment, '
#                                    'enterprise systems, and calculators and '
#                                    'other. It provides DLP products primarily '
#                                    'for use in project high-definition images; '
#                                    'calculators; and application-specific '
#                                    'integrated circuits. The company markets '
#                                    'and sells its semiconductor products '
#                                    'through direct sales and distributors, as '
#                                    'well as through its website. Texas '
#                                    'Instruments Incorporated was founded in '
#                                    '1930 and is headquartered in Dallas, '
#                                    'Texas.'},
#               'score': 0.433653057,
#               'values': []},
#              {'id': 'e61c4433-3dcc-4d28-a3b9-46081c0ced1a',
#               'metadata': {'Business Summary': 'Stryker Corporation operates '
#                                                'as a medical technology '
#                                                'company. The company operates '
#                                                'through two segments, MedSurg '
#                                                'and Neurotechnology, and '
#                                                'Orthopaedics and Spine. The '
#                                                'Orthopaedics and Spine segment '
#                                                'provides implants for use in '
#                                                'total joint replacements, such '
#                                                'as hip, knee and shoulder, and '
#                                                'trauma and extremities '
#                                                'surgeries. This segment also '
#                                                'offers spinal implant products '
#                                                'comprising cervical and '
#                                                'thoracolumbar systems that '
#                                                'include fixation, minimally '
#                                                'invasive and interbody systems '
#                                                'used in spinal injury, complex '
#                                                'spine and degenerative '
#                                                'therapies. The MedSurg and '
#                                                'Neurotechnology segment offers '
#                                                'surgical equipment, and '
#                                                'surgical navigation systems, '
#                                                'endoscopic and communications '
#                                                'systems, patient handling, '
#                                                'emergency medical equipment '
#                                                'and intensive care disposable '
#                                                'products, reprocessed and '
#                                                'remanufactured medical '
#                                                'devices, clinical '
#                                                'communication and workflow '
#                                                'solutions, and other medical '
#                                                'device products that are used '
#                                                'in various medical '
#                                                'specialties, as well as '
# ...
#                                                'trucks, wheel tractor scrapers '
#                                                'and dozers, fleet management '
#                                                'products, landfill and soil '
#                                                'compactors, machinery '
#                                                'components, autonomous ready '
#                                                'vehicles and solutions, work '
#                                                'tools, and safety services and '
#                                                'mining performance solutions, '
#                                                'as well as related parts and '
#                                                'services. Its Energy & '
#                                                'Transportation segment offers '
#                                                'reciprocating engine powered '
#                                                'generator sets; reciprocating '
#                                                'engines, drivetrain, and '
#                                                'integrated systems and '
#                                                'solutions; turbines, '
#                                                'centrifugal gas compressors, '
#                                                'and related services; and '
#                                                'diesel-electric locomotives '
#                                                'and components, and other '
#                                                'rail-related products. The '
#                                                "company's Financial Products "
#                                                'segment provides operating and '
#                                                'finance leases, installment '
#                                                'sale contracts, revolving '
#                                                'charge accounts, '
#                                                'repair/rebuild financing '
#                                                'services, working capital '
#                                                'loans, and wholesale '
#                                                'financing; and insurance and '
#                                                'risk management products and '
#                                                'services. Its All Other '
#                                                'Operating segment offers '
#                                                'filters and fluids, '
#                                                'undercarriage, ground engaging '
#                                                'tools, fluid transfer '
#                                                'products, precision seals, and '
#                                                'rubber sealing and connecting '
#                                                'components; parts '
#                                                'distribution; logistics '
#                                                'solutions and distribution '
#                                                'services; brand management and '
#                                                'marketing strategy services; '
#                                                'and digital investments '
#                                                'services. Caterpillar Inc. was '
#                                                'founded in 1925 and is '
#                                                'headquartered in Irving, '
#                                                'Texas.',
#                            'City': 'Irving',
#                            'Country': 'United States',
#                            'Industry': 'Farm & Heavy Construction Machinery',
#                            'Name': 'Caterpillar Inc.',
#                            'Sector': 'Industrials',
#                            'State': 'TX',
#                            'Ticker': 'CAT',
#                            'text': 'Caterpillar Inc. manufactures and sells '
#                                    'construction and mining equipment, '
#                                    'off-highway diesel and natural gas '
#                                    'engines, industrial gas turbines, and '
#                                    'diesel-electric locomotives in worldwide. '
#                                    'Its Construction Industries segment offers '
#                                    'asphalt pavers, compactors, road '
#                                    'reclaimers, forestry machines, cold '
#                                    'planers, material handlers, track-type '
#                                    'tractors, excavators, telehandlers, motor '
#                                    'graders, and pipelayers; compact track, '
#                                    'wheel, track-type, backhoe, and skid steer '
#                                    'loaders; and related parts and tools. The '
#                                    "company's Resource Industries segment "
#                                    'provides electric rope and hydraulic '
#                                    'shovels, draglines, rotary drills, hard '
#                                    'rock vehicles, tractors, mining trucks, '
#                                    'wheel loaders, off-highway and articulated '
#                                    'trucks, wheel tractor scrapers and dozers, '
#                                    'fleet management products, landfill and '
#                                    'soil compactors, machinery components, '
#                                    'autonomous ready vehicles and solutions, '
#                                    'work tools, and safety services and mining '
#                                    'performance solutions, as well as related '
#                                    'parts and services. Its Energy & '
#                                    'Transportation segment offers '
#                                    'reciprocating engine powered generator '
#                                    'sets; reciprocating engines, drivetrain, '
#                                    'and integrated systems and solutions; '
#                                    'turbines, centrifugal gas compressors, and '
#                                    'related services; and diesel-electric '
#                                    'locomotives and components, and other '
#                                    "rail-related products. The company's "
#                                    'Financial Products segment provides '
#                                    'operating and finance leases, installment '
#                                    'sale contracts, revolving charge accounts, '
#                                    'repair/rebuild financing services, working '
#                                    'capital loans, and wholesale financing; '
#                                    'and insurance and risk management products '
#                                    'and services. Its All Other Operating '
#                                    'segment offers filters and fluids, '
#                                    'undercarriage, ground engaging tools, '
#                                    'fluid transfer products, precision seals, '
#                                    'and rubber sealing and connecting '
#                                    'components; parts distribution; logistics '
#                                    'solutions and distribution services; brand '
#                                    'management and marketing strategy '
#                                    'services; and digital investments '
#                                    'services. Caterpillar Inc. was founded in '
#                                    '1925 and is headquartered in Irving, '
#                                    'Texas.'},
#               'score': 0.403569609,
#               'values': []},
#              {'id': '43ed9b14-e1e2-421a-848f-c09dc4bf739a',
#               'metadata': {'Business Summary': 'NVIDIA Corporation provides '
#                                                'graphics and compute and '
#                                                'networking solutions in the '
#                                                'United States, Taiwan, China, '
#                                                'Hong Kong, and '
#                                                'internationally. The Graphics '
#                                                'segment offers GeForce GPUs '
#                                                'for gaming and PCs, the '
#                                                'GeForce NOW game streaming '
#                                                'service and related '
#                                                'infrastructure, and solutions '
#                                                'for gaming platforms; '
#                                                'Quadro/NVIDIA RTX GPUs for '
#                                                'enterprise workstation '
#                                                'graphics; virtual GPU or vGPU '
#                                                'software for cloud-based '
#                                                'visual and virtual computing; '
#                                                'automotive platforms for '
#                                                'infotainment systems; and '
#                                                'Omniverse software for '
#                                                'building and operating '
#                                                'metaverse and 3D internet '
#                                                'applications. The Compute & '
#                                                'Networking segment comprises '
#                                                'Data Center computing '
#                                                'platforms and end-to-end '
#                                                'networking platforms, '
#                                                'including Quantum for '
#                                                'InfiniBand and Spectrum for '
#                                                'Ethernet; NVIDIA DRIVE '
#                                                'automated-driving platform and '
#                                                'automotive development '
#                                                'agreements; Jetson robotics '
#                                                'and other embedded platforms; '
#                                                'NVIDIA AI Enterprise and other '
#                                                'software; and DGX Cloud '
#                                                'software and services. The '
#                                                "company's products are used in "
#                                                'gaming, professional '
#                                                'visualization, data center, '
#                                                'and automotive markets. It '
#                                                'sells its products to original '
#                                                'equipment manufacturers, '
#                                                'original device manufacturers, '
#                                                'system integrators and '
#                                                'distributors, independent '
#                                                'software vendors, cloud '
#                                                'service providers, consumer '
#                                                'internet companies, add-in '
#                                                'board manufacturers, '
#                                                'distributors, automotive '
#                                                'manufacturers and tier-1 '
#                                                'automotive suppliers, and '
#                                                'other ecosystem participants. '
#                                                'NVIDIA Corporation was '
#                                                'incorporated in 1993 and is '
#                                                'headquartered in Santa Clara, '
#                                                'California.',
#                            'City': 'Santa Clara',
#                            'Country': 'United States',
#                            'Industry': 'Semiconductors',
#                            'Name': 'NVIDIA Corporation',
#                            'Sector': 'Technology',
#                            'State': 'CA',
#                            'Ticker': 'NVDA',
#                            'text': 'NVIDIA Corporation provides graphics and '
#                                    'compute and networking solutions in the '
#                                    'United States, Taiwan, China, Hong Kong, '
#                                    'and internationally. The Graphics segment '
#                                    'offers GeForce GPUs for gaming and PCs, '
#                                    'the GeForce NOW game streaming service and '
#                                    'related infrastructure, and solutions for '
#                                    'gaming platforms; Quadro/NVIDIA RTX GPUs '
#                                    'for enterprise workstation graphics; '
#                                    'virtual GPU or vGPU software for '
#                                    'cloud-based visual and virtual computing; '
#                                    'automotive platforms for infotainment '
#                                    'systems; and Omniverse software for '
#                                    'building and operating metaverse and 3D '
#                                    'internet applications. The Compute & '
#                                    'Networking segment comprises Data Center '
#                                    'computing platforms and end-to-end '
#                                    'networking platforms, including Quantum '
#                                    'for InfiniBand and Spectrum for Ethernet; '
#                                    'NVIDIA DRIVE automated-driving platform '
#                                    'and automotive development agreements; '
#                                    'Jetson robotics and other embedded '
#                                    'platforms; NVIDIA AI Enterprise and other '
#                                    'software; and DGX Cloud software and '
#                                    "services. The company's products are used "
#                                    'in gaming, professional visualization, '
#                                    'data center, and automotive markets. It '
#                                    'sells its products to original equipment '
#                                    'manufacturers, original device '
#                                    'manufacturers, system integrators and '
#                                    'distributors, independent software '
#                                    'vendors, cloud service providers, consumer '
#                                    'internet companies, add-in board '
#                                    'manufacturers, distributors, automotive '
#                                    'manufacturers and tier-1 automotive '
#                                    'suppliers, and other ecosystem '
#                                    'participants. NVIDIA Corporation was '
#                                    'incorporated in 1993 and is headquartered '
#                                    'in Santa Clara, California.'},
#               'score': 0.399822503,
#               'values': []}],
#  'namespace': 'stock-descriptions',
#  'usage': {'read_units': 6}}

# %%
contexts = [item['metadata']['text'] for item in top_matches['matches']]

# %%
augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 10]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

# %%
print(augmented_query)
# Out:
# <CONTEXT>
# 3M Company provides diversified technology services in the United States and internationally. The company's Safety and Industrial segment offers industrial abrasives and finishing for metalworking applications; autobody repair solutions; closure systems for personal hygiene products, masking, and packaging materials; electrical products and materials for construction and maintenance, power distribution, and electrical original equipment manufacturers; structural adhesives and tapes; respiratory, hearing, eye, and fall protection solutions; and natural and color-coated mineral granules for shingles. Its Transportation and Electronics segment provides ceramic solutions; attachment/bonding products, films, sound, and temperature management for transportation vehicles; premium large format graphic films for advertising and fleet signage; light management films and electronics assembly solutions; packaging and interconnection solutions; semiconductor production materials; data centers solutions; and reflective signage for highway, and vehicle safety. The company's Consumer segment provides consumer bandages, braces, supports, and consumer respirators; home cleaning products; retail abrasives, paint accessories, car care DIY products, picture hanging, and consumer air quality solutions; and stationery products. It offers its products through e-commerce and traditional wholesalers, retailers, jobbers, distributors, and dealers. 3M Company was founded in 1902 and is headquartered in Saint Paul, Minnesota.
#
# -------
#
# 3M Company provides diversified technology services in the United States and internationally. The company's Safety and Industrial segment offers industrial abrasives and finishing for metalworking applications; autobody repair solutions; closure systems for personal hygiene products, masking, and packaging materials; electrical products and materials for construction and maintenance, power distribution, and electrical original equipment manufacturers; structural adhesives and tapes; respiratory, hearing, eye, and fall protection solutions; and natural and color-coated mineral granules for shingles. Its Transportation and Electronics segment provides ceramic solutions; attachment/bonding products, films, sound, and temperature management for transportation vehicles; premium large format graphic films for advertising and fleet signage; light management films and electronics assembly solutions; packaging and interconnection solutions; semiconductor production materials; data centers solutions; and reflective signage for highway, and vehicle safety. The company's Consumer segment provides consumer bandages, braces, supports, and consumer respirators; home cleaning products; retail abrasives, paint accessories, car care DIY products, picture hanging, and consumer air quality solutions; and stationery products. It offers its products through e-commerce and traditional wholesalers, retailers, jobbers, distributors, and dealers. 3M Company was founded in 1902 and is headquartered in Saint Paul, Minnesota.
#
# -------
#
# Best Buy Co., Inc. engages in the retail of technology products in the United States, Canada, and international. Its stores provide computing and mobile phone products, such as desktops, notebooks, and peripherals; mobile phones comprising related mobile network carrier commissions; networking products; tablets covering e-readers; smartwatches; and consumer electronics consisting of digital imaging, health and fitness products, portable audio comprising headphones and portable speakers, and smart home products, as well as home theaters, which includes home theater accessories, soundbars, and televisions. The company's stores also offer appliances, such as dishwashers, laundry, ovens, refrigerators, blenders, coffee makers, vacuums, and personal care; entertainment products consisting of drones, peripherals, movies, and toys, as well as hardware and software, and virtual reality and other software products; and other products, such as baby, food and beverage, luggage, outdoor living, and sporting goods. In addition, it provides delivery, installation, memberships, repair, set-up, technical support, health-related, and warranty-related services. The company offers its products through stores and websites under the Best Buy, Best Buy Ads, Best Buy Business, Best Buy Health, Buy Mobile, CST, Current Health, Geek Squad, Lively, Magnolia, Pacific Kitchen, Home, TechLiquidators, and Yardbird brands, as well as domain names comprising bestbuy.com, currenthealth.com, lively.com, techliquidators.com, yardbird.com, and bestbuy.ca. The company was formerly known as Sound of Music, Inc. Best Buy Co., Inc. was incorporated in 1966 and is headquartered in Richfield, Minnesota.
#
# -------
#
# Best Buy Co., Inc. engages in the retail of technology products in the United States, Canada, and international. Its stores provide computing and mobile phone products, such as desktops, notebooks, and peripherals; mobile phones comprising related mobile network carrier commissions; networking products; tablets covering e-readers; smartwatches; and consumer electronics consisting of digital imaging, health and fitness products, portable audio comprising headphones and portable speakers, and smart home products, as well as home theaters, which includes home theater accessories, soundbars, and televisions. The company's stores also offer appliances, such as dishwashers, laundry, ovens, refrigerators, blenders, coffee makers, vacuums, and personal care; entertainment products consisting of drones, peripherals, movies, and toys, as well as hardware and software, and virtual reality and other software products; and other products, such as baby, food and beverage, luggage, outdoor living, and sporting goods. In addition, it provides delivery, installation, memberships, repair, set-up, technical support, health-related, and warranty-related services. The company offers its products through stores and websites under the Best Buy, Best Buy Ads, Best Buy Business, Best Buy Health, Buy Mobile, CST, Current Health, Geek Squad, Lively, Magnolia, Pacific Kitchen, Home, TechLiquidators, and Yardbird brands, as well as domain names comprising bestbuy.com, currenthealth.com, lively.com, techliquidators.com, yardbird.com, and bestbuy.ca. The company was formerly known as Sound of Music, Inc. Best Buy Co., Inc. was incorporated in 1966 and is headquartered in Richfield, Minnesota.
#
# -------
#
# Hubbell Incorporated, together with its subsidiaries, designs, manufactures, and sells electrical and utility solutions in the United States and internationally. It operates through two segments, Electrical Solutions and Utility Solutions. The Electrical Solution segment offers standard and special application wiring device products, rough-in electrical products, connector and grounding products, lighting fixtures, and other electrical equipment for use in industrial, commercial, and institutional facilities by electrical contractors, maintenance personnel, electricians, utilities, and telecommunications companies, as well as components and assemblies. It also designs and manufactures various industrial controls, and communication systems for use in the non-residential and industrial markets, as well as in the oil and gas, and mining industries. This segment sells its products through electrical and industrial distributors, home centers, retail and hardware outlets, lighting showrooms, and residential product-oriented internet sites; and special application products primarily through wholesale distributors to contractors, industrial customers, and original equipment manufacturers. The Utility Solution segment designs, manufactures, and sells electrical distribution, transmission, substation, and telecommunications products, such as arresters, insulators, connectors, anchors, bushings, and enclosures cutoffs and switches; and utility infrastructure products, including smart meters, communications systems, and protection and control devices. This segment sells its products to distributors. Its brand portfolio includes Hubbell, Kellems, Bryant, Burndy, CMC, Bell, TayMac, Wiegmann, Killark, Hawke, Aclara, Fargo, Quazite, Hot Box, etc. The company was founded in 1888 and is headquartered in Shelton, Connecticut.
#
# -------
#
# Hubbell Incorporated, together with its subsidiaries, designs, manufactures, and sells electrical and utility solutions in the United States and internationally. It operates through two segments, Electrical Solutions and Utility Solutions. The Electrical Solution segment offers standard and special application wiring device products, rough-in electrical products, connector and grounding products, lighting fixtures, and other electrical equipment for use in industrial, commercial, and institutional facilities by electrical contractors, maintenance personnel, electricians, utilities, and telecommunications companies, as well as components and assemblies. It also designs and manufactures various industrial controls, and communication systems for use in the non-residential and industrial markets, as well as in the oil and gas, and mining industries. This segment sells its products through electrical and industrial distributors, home centers, retail and hardware outlets, lighting showrooms, and residential product-oriented internet sites; and special application products primarily through wholesale distributors to contractors, industrial customers, and original equipment manufacturers. The Utility Solution segment designs, manufactures, and sells electrical distribution, transmission, substation, and telecommunications products, such as arresters, insulators, connectors, anchors, bushings, and enclosures cutoffs and switches; and utility infrastructure products, including smart meters, communications systems, and protection and control devices. This segment sells its products to distributors. Its brand portfolio includes Hubbell, Kellems, Bryant, Burndy, CMC, Bell, TayMac, Wiegmann, Killark, Hawke, Aclara, Fargo, Quazite, Hot Box, etc. The company was founded in 1888 and is headquartered in Shelton, Connecticut.
#
# -------
#
# Masco Corporation designs, manufactures, and distributes home improvement and building products in North America, Europe, and internationally. The company's Plumbing Products segment offers faucets, showerheads, handheld showers, valves, bath hardware and accessories, bathing units, shower bases and enclosures, sinks, toilets, acrylic tubs, shower trays, spas, exercise pools, and fitness systems; brass, copper, and composite plumbing system components; connected water products; thermoplastic solutions, extruded plastic profiles, specialized fabrications, and PEX tubing products; and other non-decorative plumbing products. This segment provides its products under the DELTA, BRIZO, PEERLESS, HANSGROHE, AXOR, KRAUS, EASY DRAIN, STEAMIST, ELITESTEAM, GINGER, NEWPORT BRASS, BRASSTECH, WALTEC, BRISTAN, HERITAGE, MIROLIN, HOT SPRING, CALDERA, FREEFLOW SPAS, FANTASY SPAS, ENDLESS POOLS, BRASSCRAFT, PLUMB SHOP, COBRA, COBRA PRO, and MASTER PLUMBER brands. Its Decorative Architectural Products segment offers paints, primers, specialty coatings, stains, and waterproofing products, as well as paint applicators and accessories; cabinet and door hardware, functional hardware, wall plates, hook and rail products, closet organization systems, and picture hanging accessories; decorative bath hardware, mirrors, and shower accessories and doors; and decorative indoor and outdoor lighting fixtures, ceiling fans, landscape lighting, and LED lighting systems. This segment provides its products under the BEHR, KILZ, WHIZZ, Elder & Jenks, LIBERTY, BRAINERD, FRANKLIN BRASS, KICHLER, and ÉLAN brands. It sells its products to the plumbing, heating, and hardware wholesalers; home centers and online retailers; hardware stores; electrical and landscape distributors; lighting showrooms; building supply outlets; and other mass merchandisers. Masco Corporation was incorporated in 1929 and is headquartered in Livonia, Michigan.
#
# -------
#
# Masco Corporation designs, manufactures, and distributes home improvement and building products in North America, Europe, and internationally. The company's Plumbing Products segment offers faucets, showerheads, handheld showers, valves, bath hardware and accessories, bathing units, shower bases and enclosures, sinks, toilets, acrylic tubs, shower trays, spas, exercise pools, and fitness systems; brass, copper, and composite plumbing system components; connected water products; thermoplastic solutions, extruded plastic profiles, specialized fabrications, and PEX tubing products; and other non-decorative plumbing products. This segment provides its products under the DELTA, BRIZO, PEERLESS, HANSGROHE, AXOR, KRAUS, EASY DRAIN, STEAMIST, ELITESTEAM, GINGER, NEWPORT BRASS, BRASSTECH, WALTEC, BRISTAN, HERITAGE, MIROLIN, HOT SPRING, CALDERA, FREEFLOW SPAS, FANTASY SPAS, ENDLESS POOLS, BRASSCRAFT, PLUMB SHOP, COBRA, COBRA PRO, and MASTER PLUMBER brands. Its Decorative Architectural Products segment offers paints, primers, specialty coatings, stains, and waterproofing products, as well as paint applicators and accessories; cabinet and door hardware, functional hardware, wall plates, hook and rail products, closet organization systems, and picture hanging accessories; decorative bath hardware, mirrors, and shower accessories and doors; and decorative indoor and outdoor lighting fixtures, ceiling fans, landscape lighting, and LED lighting systems. This segment provides its products under the BEHR, KILZ, WHIZZ, Elder & Jenks, LIBERTY, BRAINERD, FRANKLIN BRASS, KICHLER, and ÉLAN brands. It sells its products to the plumbing, heating, and hardware wholesalers; home centers and online retailers; hardware stores; electrical and landscape distributors; lighting showrooms; building supply outlets; and other mass merchandisers. Masco Corporation was incorporated in 1929 and is headquartered in Livonia, Michigan.
#
# -------
#
# TransDigm Group Incorporated designs, produces, and supplies aircraft components in the United States and internationally. The Power & Control segment offers mechanical/electro-mechanical actuators and controls, ignition systems and engine technology, specialized pumps and valves, power conditioning devices, specialized AC/DC electric motors and generators, batteries and chargers, databus and power controls, sensor products, switches and relay panels, hoists, winches and lifting devices, delivery systems and electronic components, and cargo loading and handling systems. This segment serves engine and power system and subsystem suppliers, airlines, third party maintenance suppliers, military buying agencies, and repair depots. The Airframe segment provides engineered latching and locking devices, engineered rods, engineered connectors and elastomer sealing solutions, cockpit security components and systems, cockpit displays, engineered audio, radio and antenna systems, lavatory components, seat belts and safety restraints, engineered and customized interior surfaces and related components, thermal protection and insulation products, lighting and control technology, parachutes, specialized flight, wind tunnel and jet engine testing services and equipment, and testing and instrumentation solutions. This segment serves airframe manufacturers, cabin system and subsystem suppliers, airlines, third party maintenance suppliers, military buying agencies, and repair depots. The Non-aviation segment offers seat belts and safety restraints; mechanical/electromechanical actuators and controls; hydraulic/electromechanical actuators and fuel valves; refueling systems; and turbine controls. This segment serves off-road vehicle and subsystem suppliers, child restraint system suppliers, and satellite and space system suppliers; and manufacturers of heavy equipment. TransDigm Group Incorporated was founded in 1993 and is based in Cleveland, Ohio.
#
# -------
#
# TransDigm Group Incorporated designs, produces, and supplies aircraft components in the United States and internationally. The Power & Control segment offers mechanical/electro-mechanical actuators and controls, ignition systems and engine technology, specialized pumps and valves, power conditioning devices, specialized AC/DC electric motors and generators, batteries and chargers, databus and power controls, sensor products, switches and relay panels, hoists, winches and lifting devices, delivery systems and electronic components, and cargo loading and handling systems. This segment serves engine and power system and subsystem suppliers, airlines, third party maintenance suppliers, military buying agencies, and repair depots. The Airframe segment provides engineered latching and locking devices, engineered rods, engineered connectors and elastomer sealing solutions, cockpit security components and systems, cockpit displays, engineered audio, radio and antenna systems, lavatory components, seat belts and safety restraints, engineered and customized interior surfaces and related components, thermal protection and insulation products, lighting and control technology, parachutes, specialized flight, wind tunnel and jet engine testing services and equipment, and testing and instrumentation solutions. This segment serves airframe manufacturers, cabin system and subsystem suppliers, airlines, third party maintenance suppliers, military buying agencies, and repair depots. The Non-aviation segment offers seat belts and safety restraints; mechanical/electromechanical actuators and controls; hydraulic/electromechanical actuators and fuel valves; refueling systems; and turbine controls. This segment serves off-road vehicle and subsystem suppliers, child restraint system suppliers, and satellite and space system suppliers; and manufacturers of heavy equipment. TransDigm Group Incorporated was founded in 1993 and is based in Cleveland, Ohio.
# -------
# </CONTEXT>
#
#
#
# MY QUESTION:
# What are some companies that manufacture consumer hardware?

# %% [markdown]
# # Setting up Groq for RAG
#
# 1. Get your Groq API Key [here](https://console.groq.com/keys). Through Groq, you get free access to various LLMs
#
# 2. Paste your Groq API Key into your Google Colab secrets, and make sure to enable permissions for it
#
# ![Screenshot 2024-11-25 at 12 00 16 AM](https://github.com/user-attachments/assets/e5525d29-bca6-4dbd-892b-cc770a6b281d)

# %%
import os
# !pip install groq
from groq import Groq

client = Groq(
    api_key= userdata.get("GROQ_API_KEY"),
)
# chat_completion = client.chat.completions.create(
#     messages=[
#         {
#             "role": "user",
#             "content": "Explain the importance of fast language models",
#         }
#     ],
#     model="llama3-8b-8192",
# )

# print(chat_completion.choices[0].message.content)

# %%
import openai

# client = OpenAI(
#   base_url="https://api.groq.com/openai/v1",
#   api_key=userdata.get("GROQ_API_KEY")
# )

system_prompt = f"""You are an expert at providing answers about stocks. Please answer my question provided.
"""

llm_response = client.chat.completions.create(
    model="llama-3.1-70b-versatile",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": augmented_query}
    ]
)

response = llm_response.choices[0].message.content

print(response)
# Out:
# Based on the context provided, some companies that manufacture consumer hardware are:
#
# 1. 3M Company (industrial abrasives, home cleaning products, and consumer air quality solutions)
# 2. Best Buy Co., Inc. (consumer electronics, appliances, and home improvement products)
# 3. Hubbell Incorporated (electrical solutions, lighting fixtures, and smart home products)
# 4. Masco Corporation (plumbing, cabinetry, and lighting fixtures for home improvement)
#
# These companies have a range of consumer-facing products in their portfolios, catering to various aspects of home and personal life, such as cleaning, lighting, home improvement, and electronics.
#
# However, there is no direct link to a specific business segment in 3M company nor to a Masco's business segment, that is well described.
#
# I would recommend best Buy Co and Hubbell Inc.

# %%
augmented_query
# Out:
# 'Explain the importance of fast language models.'

# %%
print(response)
# Out:
# Based on the context provided, some companies that manufacture consumer hardware are:
#
# 1. 3M Company (industrial abrasives, home cleaning products, and consumer air quality solutions)
# 2. Best Buy Co., Inc. (consumer electronics, appliances, and home improvement products)
# 3. Hubbell Incorporated (electrical solutions, lighting fixtures, and smart home products)
# 4. Masco Corporation (plumbing, cabinetry, and lighting fixtures for home improvement)
#
# These companies have a range of consumer-facing products in their portfolios, catering to various aspects of home and personal life, such as cleaning, lighting, home improvement, and electronics.
#
# However, there is no direct link to a specific business segment in 3M company nor to a Masco's business segment, that is well described.
#
# I would recommend best Buy Co and Hubbell Inc.

# %% [markdown]
# # StreamLit App

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.40.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<12,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (11.0.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.9.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit)
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 2.4 MB/s eta 0:00:00
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.1.43)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.4.0->streamlit) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.8.30)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.16.0)
# Downloading streamlit-1.40.2-py2.py3-none-any.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 74.8 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 92.8 MB/s eta 0:00:00
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 7.4 MB/s eta 0:00:00
# Installing collected packages: watchdog, pydeck, streamlit
# Successfully installed pydeck-0.9.1 streamlit-1.40.2 watchdog-6.0.0

# %%
# %%writefile app.py

import streamlit as st

st.title('Find me a STOCK!')
# Out:
# Overwriting app.py

# %%
# !streamlit run /content/app.py --server.port 8501
# Out:
# /bin/bash: line 1: streamlit: command not found

# %%
import os

def run_streamlit():
  os.system("streamlit run /content/app.py --server.port 8501")

# %%
run_streamlit()

# %%
from threading import Thread # to run colab and strramlit app simultabeoudly, to let the server to run simultaneously
from pyngrok import ngrok # to create seprate URL for the app - creates a secure tunnel to make the local host accesbile on public url
from google.colab import userdata
import os

# %%
ngrok_token = userdata.get('NGROK_AUTH_TOKEN')
ngrok.set_auth_token (ngrok_token)

# %%
tunnels = ngrok.get_tunnels ()
for tunnel in tunnels:
  print(f"Closing tunnel: {tunnel.public_url} → {tunnel. config['addr']}")
  ngrok. disconnect (tunnel.public_url)
# Out:
# WARNING:pyngrok.process.ngrok:t=2024-12-10T03:18:42+0000 lvl=warn msg="Stopping forwarder" name=http-8501-d900b1e6-50e6-4212-9b36-29368ab033b9 acceptErr="failed to accept connection: Listener closed"
# Closing tunnel: https://e4c6-104-199-215-50.ngrok-free.app → http://localhost:8501

# %%
thread = Thread (target=run_streamlit)
thread.start()

# %%
public_url = ngrok. connect (addr='8501', proto='http', bind_tls=True)
print ("Public URL:", public_url)
# Out:
# Public URL: NgrokTunnel: "https://f4d3-104-199-215-50.ngrok-free.app" -> "http://localhost:8501"
